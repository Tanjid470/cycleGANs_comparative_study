# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch import nn, optim

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ### Loading Data

# %%
from PIL import Image
import torch
import os
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

def get_data_loader(image_type, image_dir='/content/drive/MyDrive/ColabNotebooks/DataSet/apple2orange', image_size=128, batch_size=16, num_workers=0):
    """Returns: training and test data loaders for a given image type, either summer or winter"""

    # Resize and normalize the images
    transform = transforms.Compose([
        transforms.Resize((image_size, image_size), interpolation=Image.BICUBIC),  # Resize images to have dimensions (image_size, image_size)
        transforms.ToTensor()  # Convert images to PyTorch tensors
    ])

    # Get training and test directories
    train_path = os.path.join(image_dir, image_type)
    test_path = os.path.join(image_dir, 'test_{}'.format(image_type))

    # Define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)
    test_dataset = datasets.ImageFolder(test_path, transform)

    # Create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    # Retrieve a sample image from the training dataset for visualization
    sample_image, _ = train_dataset[7]

    # Resize to 256x256 (if not already done by transform)
    sample_image = transforms.Resize((256, 256))(sample_image)

    # Extract the red, green, and blue channels
    red_channel = sample_image[0, :, :]
    green_channel = sample_image[1, :, :]
    blue_channel = sample_image[2, :, :]

    # Normalize the channels to [0, 1]
    red_channel_normalized = red_channel / torch.max(red_channel)
    green_channel_normalized = green_channel / torch.max(green_channel)
    blue_channel_normalized = blue_channel / torch.max(blue_channel)

    # Convert to numpy for visualization
    red_channel_normalized_np = red_channel_normalized.numpy()
    green_channel_normalized_np = green_channel_normalized.numpy()
    blue_channel_normalized_np = blue_channel_normalized.numpy()

    # Display the images in a single row
    plt.figure(figsize=(25, 5))

    # Original Image
    plt.subplot(1, 6, 1)
    plt.imshow(sample_image.permute(1, 2, 0))
    plt.title('Original Image')
    plt.axis('off')

    # Red Amplitude Image
    plt.subplot(1, 6, 2)
    plt.imshow(red_channel_normalized_np, cmap='Reds')
    plt.title('Red Channel')
    plt.axis('off')

    # Green Amplitude Image
    plt.subplot(1, 6, 3)
    plt.imshow(green_channel_normalized_np, cmap='Greens')
    plt.title('Green Channel')
    plt.axis('off')

    # Blue Amplitude Image
    plt.subplot(1, 6, 4)
    plt.imshow(blue_channel_normalized_np, cmap='Blues')
    plt.title('Blue Channel')
    plt.axis('off')

    # Transformed Image (same as original in this case)
    plt.subplot(1, 6, 5)
    np_image = sample_image.numpy().transpose((1, 2, 0))
    plt.imshow(np_image)
    plt.title('Transformed Image')
    plt.axis('off')

    # Grayscale Image
    grayscale_transform = transforms.Grayscale(num_output_channels=3)
    grayscale_image = grayscale_transform(sample_image)

    plt.subplot(1, 6, 6)
    plt.imshow(grayscale_image.permute(1, 2, 0))
    plt.title('Grayscale Image')
    plt.axis('off')

    plt.show()

    return train_loader, test_loader

# %% [markdown]
# ####Resize and Normalize Output Check

# %%
dataloader_X, test_dataloader_X = get_data_loader(image_type='apple')
dataloader_Y, test_dataloader_Y = get_data_loader(image_type='orange')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# display sample images
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_X is your DataLoader
dataiter = iter(dataloader_X)
images, _ = next(dataiter)  # Use next() directly to get the next batch

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_Y is your DataLoader
dataiter = iter(dataloader_Y)

# Get the first batch from the dataloader
for images, _ in dataiter:
    break

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %% [markdown]
# ### Building the Model

# %%
img = images[3]
print('min: ', img.min())
print('max: ', img.max())
# Out:
# min:  tensor(0.)
# max:  tensor(1.)

# %% [markdown]
# #### Discriminator

# %%
# Define a helper function for creating convolutional layers
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
# Discriminator Class
class Discriminator(nn.Module):
    def __init__(self, conv_dim=64):
        super(Discriminator, self).__init__()
        # Define all convolutional layers
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1, batch_norm=False)  # 64x64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 32x32x128
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 16x16x256
        self.conv4 = conv(conv_dim * 4, conv_dim * 8, 4, stride=2, padding=1)  # 8x8x512
        # Final layer
        self.conv5 = nn.Conv2d(conv_dim * 8, 1, 4, stride=1, padding=0, bias=False)  # 1x1x1

    def forward(self, x):
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = nn.ReLU()(self.conv4(out))
        out = self.conv5(out)
        out = torch.sigmoid(out)  # Add sigmoid for output
        return out.view(-1)  # Flatten to 1D for output

# %%
# Residual block definition
class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv(dim, dim, kernel_size=3, stride=1, padding=1)
        self.conv2 = conv(dim, dim, kernel_size=3, stride=1, padding=1, batch_norm=False)

    def forward(self, x):
        residual = x
        x = nn.ReLU()(self.conv1(x))
        x = self.conv2(x)
        return x + residual  # Adding residual for skip connection

# %%
def deconv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(deconv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### CycleGenerator

# %%
# CycleGenerator Class
class CycleGenerator(nn.Module):
    def __init__(self, conv_dim=64, n_res_blocks=6):
        super(CycleGenerator, self).__init__()
        # 1. Encoder
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1)  # 128x128 -> 64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 64x64 -> 32x32
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 32x32 -> 16x16

        # 2. Residual blocks
        res_layers = []
        for _ in range(n_res_blocks):
            res_layers.append(ResidualBlock(conv_dim * 4))
        self.res_blocks = nn.Sequential(*res_layers)

        # 3. Decoder
        self.deconv1 = deconv(conv_dim * 4, conv_dim * 2, 4, stride=2, padding=1)  # 16x16 -> 32x32
        self.deconv2 = deconv(conv_dim * 2, conv_dim, 4, stride=2, padding=1)  # 32x32 -> 64x64
        self.deconv3 = deconv(conv_dim, 3, 4, stride=2, padding=1, batch_norm=False)  # 64x64 -> 128x128

    def forward(self, x):
        """Transforms an image and returns it."""
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = self.res_blocks(out)
        out = nn.ReLU()(self.deconv1(out))
        out = nn.ReLU()(self.deconv2(out))
        # Apply tanh activation to the final output
        out = nn.Tanh()(self.deconv3(out))
        return out

# %% [markdown]
# ### Complete Network

# %%
# Assuming CycleGenerator and Discriminator are defined elsewhere

def create_model(
    g_conv_dim=64,
    d_conv_dim=64,
    n_res_blocks=6,
    device=None
):
    """Builds and initializes generators and discriminators for CycleGAN."""
    # Assign the device if not provided
    if device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Instantiate generators
    G_XtoY = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)
    G_YtoX = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)

    # Instantiate discriminators
    D_X = Discriminator(conv_dim=d_conv_dim).to(device)
    D_Y = Discriminator(conv_dim=d_conv_dim).to(device)

    # Log the device information
    if device.type == "cuda":
        print(f"Models moved to GPU: {torch.cuda.get_device_name(device)}.")
    else:
        print("Models using CPU.")

    # Return the initialized models
    return G_XtoY, G_YtoX, D_X, D_Y

# %%
G_XtoY, G_YtoX, D_X, D_Y = create_model()
# Out:
# Models moved to GPU: Tesla T4.

# %%
def print_models(G_XtoY, G_YtoX, D_X, D_Y):
    """Prints model information for the generators and discriminators.
    """
    print("                     G_XtoY                    ")
    print("-----------------------------------------------")
    print(G_XtoY)
    print()

    print("                     G_YtoX                    ")
    print("-----------------------------------------------")
    print(G_YtoX)
    print()

    print("                      D_X                      ")
    print("-----------------------------------------------")
    print(D_X)
    print()

    print("                      D_Y                      ")
    print("-----------------------------------------------")
    print(D_Y)
    print()


# print all of the models
print_models(G_XtoY, G_YtoX, D_X, D_Y)
# Out:
#                      G_XtoY
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                      G_YtoX
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                       D_X
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
#
#                       D_Y
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %% [markdown]
# #### GANs loss

# %%
def real_mse_loss(D_out):
    # how close is the produced output from being "real"?
    return torch.mean((D_out-1)**2)

# %%
def fake_mse_loss(D_out):
    # how close is the produced output from being "fake"?
    return torch.mean(D_out**2)

# %%
def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    # calculate reconstruction loss
    # as absolute value difference between the real and reconstructed images
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    # return weighted loss
    return lambda_weight*reconstr_loss

# %% [markdown]
# ### Optimizers

# %%
# hyperparams for Adam optimizer
lr=0.0002
beta1=0.5
beta2=0.999 # default value

# %%
# Get generator parameters
g_params = list(G_XtoY.parameters()) + list(G_YtoX.parameters())

# %%
# Create optimizers for the generators and discriminators
g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ### Helper functions

# %%
import pdb
import pickle
import argparse
import scipy
import scipy.misc

# %%
warnings.filterwarnings("ignore")

# %%
def checkpoint(iteration, G_XtoY, G_YtoX, D_X, D_Y, checkpoint_dir='/content/drive/MyDrive/ColabNotebooks/model_checkpoints'):
    """saves the parameters of both generators G_YtoX, G_XtoY and discriminators D_X, D_Y"""
    G_XtoY_path = os.path.join(checkpoint_dir, 'G_XtoY.pkl')
    G_YtoX_path = os.path.join(checkpoint_dir, 'G_YtoX.pkl')
    D_X_path = os.path.join(checkpoint_dir, 'D_X.pkl')
    D_Y_path = os.path.join(checkpoint_dir, 'D_Y.pkl')
    torch.save(G_XtoY.state_dict(), G_XtoY_path)
    torch.save(G_YtoX.state_dict(), G_YtoX_path)
    torch.save(D_X.state_dict(), D_X_path)
    torch.save(D_Y.state_dict(), D_Y_path)

# %%
import numpy as np

def merge_images(sources, targets, batch_size=16):
    """
    Merges source and target image batches into a single image for visualization.

    Args:
    - sources (numpy array): Source images of shape (B, C, H, W).
    - targets (numpy array): Target images of shape (B, C, H, W).
    - batch_size (int): Number of images in each batch.

    Returns:
    - merged (numpy array): Merged image with source and target pairs side-by-side.
    """
    # Check if batch_size matches the number of images
    if len(sources) != batch_size or len(targets) != batch_size:
        raise ValueError("Batch size does not match the number of images in sources or targets.")

    # Get height and width from source images
    _, channels, height, width = sources.shape

    # Calculate number of rows for the merged image (square layout)
    row = int(np.sqrt(batch_size))

    # Initialize an empty array for the merged image
    # This will contain source and target pairs side-by-side
    merged = np.zeros((channels, row * height, row * width * 2))

    # Loop through the batches to fill the merged array
    for idx, (source, target) in enumerate(zip(sources, targets)):
        # Determine row and column index for placement
        row_idx = idx // row
        col_idx = idx % row

        # Place the source and target images into the merged array
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2) * width:(col_idx * 2 + 1) * width] = source
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2 + 1) * width:(col_idx * 2 + 2) * width] = target

    # Transpose the merged array for the correct (H, W, C) format
    merged = merged.transpose(1, 2, 0)

    return merged

# %%
def to_data(x):
    """converts variable to numpy."""
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

# %%
import os
import imageio
def save_samples(iteration, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16, sample_dir='image_samples'):
    """saves samples from both generators X->Y and Y->X."""
    # move input data to correct device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    fake_X = G_YtoX(fixed_Y.to(device))
    fake_Y = G_XtoY(fixed_X.to(device))

    X, fake_X = to_data(fixed_X), to_data(fake_X)
    Y, fake_Y = to_data(fixed_Y), to_data(fake_Y)

    # Create directory if it doesn't exist
    os.makedirs(sample_dir, exist_ok=True)


    merged = merge_images(X, fake_Y, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

    merged = merge_images(Y, fake_X, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ### Training the Model

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1.
       This function assumes that the input x is already scaled from 0-1.'''

    # scale from 0-1 to feature_range
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
def unnormalize_images(images):
    """ Return tensor of images to [0:255] space from [-1:1] for plotting. """
    unnormalized = torch.zeros_like(images)
    t = transforms.Normalize(
        mean=[-0.5 / 0.5, -0.5 / 0.5, -0.5 / 0.5],
        std=[1 / 0.5, 1 / 0.5, 1 / 0.5])
    for i, image in enumerate(images):
        unnormalized[i] = t(image)*255
    return unnormalized

# %%
global epoch_d_x_loss
epoch_d_x_loss = 0
global epoch_d_y_loss
epoch_d_y_loss = 0
global epoch_g_loss
epoch_g_loss = 0

# %%
def training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=100):
    print_every=10


    # Create optimizers for the generators and discriminators
    g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
    d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
    d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

    # keep track of losses over time
    losses = []

    test_iter_X = iter(test_dataloader_X)
    test_iter_Y = iter(test_dataloader_Y)

    # Get some fixed data from domains X and Y for sampling. These are images that are held
    # constant throughout training, that allow us to inspect the model's performance.
    fixed_X = next(test_iter_X)[0]
    fixed_Y = next(test_iter_Y)[0]
    fixed_X = scale(fixed_X) # make sure to scale to a range -1 to 1
    fixed_Y = scale(fixed_Y)

    # batches per epoch
    iter_X = iter(dataloader_X)
    iter_Y = iter(dataloader_Y)
    batches_per_epoch = min(len(iter_X), len(iter_Y))

    for epoch in range(1, n_epochs+1):
        # Reset iterators for each epoch
        if epoch % batches_per_epoch == 0:
            iter_X = iter(dataloader_X)
            iter_Y = iter(dataloader_Y)

        images_X, _ = next(iter_X)
        real_images = images_X
        images_X = scale(images_X) # make sure to scale to a range -1 to 1

        images_Y, _ = next(iter_Y)
        real_images = images_Y
        images_Y = scale(images_Y)

        # move images to GPU if available (otherwise stay on CPU)
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_X = images_X.to(device)
        images_Y = images_Y.to(device)


        # ============================================
        #            TRAIN THE DISCRIMINATORS
        # ============================================

        ##   First: D_X, real and fake loss components   ##

        # Train with real images
        d_x_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_x = D_X(images_X)
        D_X_real_loss = real_mse_loss(out_x)

        # Train with fake images

        # 2. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 3. Compute the fake loss for D_X
        out_x = D_X(fake_X)
        D_X_fake_loss = fake_mse_loss(out_x)


        # 4. Compute the total loss and perform backprop
        d_x_loss = D_X_real_loss + D_X_fake_loss
        d_x_loss.backward()
        d_x_optimizer.step()


        ##   Second: D_Y, real and fake loss components   ##

        # Train with real images
        d_y_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_y = D_Y(images_Y)
        D_Y_real_loss = real_mse_loss(out_y)

        # Train with fake images

        # 2. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 3. Compute the fake loss for D_Y
        out_y = D_Y(fake_Y)
        D_Y_fake_loss = fake_mse_loss(out_y)

        # 4. Compute the total loss and perform backprop
        d_y_loss = D_Y_real_loss + D_Y_fake_loss
        d_y_loss.backward()
        d_y_optimizer.step()


        # =========================================
        #            TRAIN THE GENERATORS
        # =========================================

        ##    First: generate fake X images and reconstructed Y images    ##
        g_optimizer.zero_grad()

        # 1. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 2. Compute the generator loss based on domain X
        out_x = D_X(fake_X)
        g_YtoX_loss = real_mse_loss(out_x)

        # 3. Create a reconstructed y
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_Y = G_XtoY(fake_X)

        reconstructed_y_loss = cycle_consistency_loss(images_Y, reconstructed_Y, lambda_weight=10)


        ##    Second: generate fake Y images and reconstructed X images    ##

        # 1. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 2. Compute the generator loss based on domain Y
        out_y = D_Y(fake_Y)
        g_XtoY_loss = real_mse_loss(out_y)

        # 3. Create a reconstructed x
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_X = G_YtoX(fake_Y)
        reconstructed_x_loss = cycle_consistency_loss(images_X, reconstructed_X, lambda_weight=10)

        # 5. Add up all generator and reconstructed losses and perform backprop
        g_total_loss = g_YtoX_loss + g_XtoY_loss + reconstructed_y_loss + reconstructed_x_loss
        g_total_loss.backward()
        g_optimizer.step()
        global epoch_d_x_loss
        global epoch_d_y_loss
        global epoch_g_loss

        # Print the log info
        if epoch % print_every == 0:

            # append real and fake discriminator losses and the generator loss
            losses.append((d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))

            # Sum calculating of losses
            epoch_d_x_loss += d_x_loss.item()
            epoch_d_y_loss += d_y_loss.item()
            epoch_g_loss += g_total_loss.item()

            # generate image
            X_fake = G_XtoY(images_X)
            X_fake = unnormalize_images(X_fake)
            images_X = unnormalize_images(images_X)
            grid_image_real = torchvision.utils.make_grid(images_X.cpu())
            grid_image_fake = torchvision.utils.make_grid(X_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))
            # plt.figure(figsize=(20, 10))
            # plt.imshow(saveim)
            # plt.savefig(filename + '_' + 'XtoY.jpg')

            Y_fake = G_YtoX(images_Y)
            Y_fake = unnormalize_images(Y_fake)
            images_Y = unnormalize_images(images_Y)
            grid_image_real = torchvision.utils.make_grid(images_Y.cpu())
            grid_image_fake = torchvision.utils.make_grid(Y_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))



        sample_every=100
        # Save the generated samples
        if epoch % sample_every == 0:
            G_YtoX.eval() # set generators to eval mode for sample generation
            G_XtoY.eval()
            save_samples(epoch, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16)
            G_YtoX.train()
            G_XtoY.train()

        # uncomment these lines, if you want to save your model
        checkpoint_every=1000
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, G_XtoY, G_YtoX, D_X, D_Y)

    return losses

# %%
n_epochs = 3000
losses = training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=n_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 0.0764 | d_Y_loss: 0.0005 | g_total_loss: 3.9437
# Epoch [   20/ 5000] | d_X_loss: 0.0365 | d_Y_loss: 0.0000 | g_total_loss: 4.0116
# Epoch [   30/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0022 | g_total_loss: 3.6726
# Epoch [   40/ 5000] | d_X_loss: 0.0161 | d_Y_loss: 0.0002 | g_total_loss: 3.9273
# Epoch [   50/ 5000] | d_X_loss: 0.0318 | d_Y_loss: 0.0008 | g_total_loss: 3.7246
# Epoch [   60/ 5000] | d_X_loss: 0.0043 | d_Y_loss: 0.0000 | g_total_loss: 3.6058
# Epoch [   70/ 5000] | d_X_loss: 0.0205 | d_Y_loss: 0.0000 | g_total_loss: 3.5990
# Epoch [   80/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 3.5526
# Epoch [   90/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0000 | g_total_loss: 4.1432
# Epoch [  100/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0000 | g_total_loss: 3.6144
# Saved image_samples/sample-000100-X-Y.png
# Saved image_samples/sample-000100-Y-X.png
# Epoch [  110/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0000 | g_total_loss: 3.7779
# Epoch [  120/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 0.0000 | g_total_loss: 3.5090
# Epoch [  130/ 5000] | d_X_loss: 0.0255 | d_Y_loss: 0.0000 | g_total_loss: 3.7176
# Epoch [  140/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5366
# Epoch [  150/ 5000] | d_X_loss: 0.0044 | d_Y_loss: 0.0000 | g_total_loss: 3.6504
# Epoch [  160/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0000 | g_total_loss: 3.4197
# Epoch [  170/ 5000] | d_X_loss: 0.3641 | d_Y_loss: 0.0000 | g_total_loss: 3.2255
# Epoch [  180/ 5000] | d_X_loss: 0.0545 | d_Y_loss: 0.0000 | g_total_loss: 3.5824
# Epoch [  190/ 5000] | d_X_loss: 0.0178 | d_Y_loss: 0.0000 | g_total_loss: 3.5902
# Epoch [  200/ 5000] | d_X_loss: 0.0195 | d_Y_loss: 0.0000 | g_total_loss: 3.7887
# Saved image_samples/sample-000200-X-Y.png
# Saved image_samples/sample-000200-Y-X.png
# Epoch [  210/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0000 | g_total_loss: 3.9822
# Epoch [  220/ 5000] | d_X_loss: 0.0077 | d_Y_loss: 0.0017 | g_total_loss: 3.6202
# Epoch [  230/ 5000] | d_X_loss: 0.0071 | d_Y_loss: 0.0000 | g_total_loss: 3.6345
# Epoch [  240/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0000 | g_total_loss: 3.7050
# Epoch [  250/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0000 | g_total_loss: 3.5564
# Epoch [  260/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0000 | g_total_loss: 3.7837
# Epoch [  270/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0000 | g_total_loss: 3.3292
# Epoch [  280/ 5000] | d_X_loss: 0.0137 | d_Y_loss: 0.0001 | g_total_loss: 3.6972
# Epoch [  290/ 5000] | d_X_loss: 0.0355 | d_Y_loss: 0.0000 | g_total_loss: 3.5329
# Epoch [  300/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.7547
# Saved image_samples/sample-000300-X-Y.png
# Saved image_samples/sample-000300-Y-X.png
# Epoch [  310/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0000 | g_total_loss: 3.7785
# Epoch [  320/ 5000] | d_X_loss: 0.0425 | d_Y_loss: 0.0000 | g_total_loss: 3.4912
# Epoch [  330/ 5000] | d_X_loss: 0.0274 | d_Y_loss: 0.0000 | g_total_loss: 3.5517
# Epoch [  340/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0000 | g_total_loss: 3.5578
# Epoch [  350/ 5000] | d_X_loss: 0.1648 | d_Y_loss: 0.0000 | g_total_loss: 3.4701
# Epoch [  360/ 5000] | d_X_loss: 0.0156 | d_Y_loss: 0.0000 | g_total_loss: 3.8024
# Epoch [  370/ 5000] | d_X_loss: 0.0054 | d_Y_loss: 0.0000 | g_total_loss: 4.0003
# Epoch [  380/ 5000] | d_X_loss: 0.0106 | d_Y_loss: 0.0000 | g_total_loss: 3.5597
# Epoch [  390/ 5000] | d_X_loss: 0.0741 | d_Y_loss: 0.0000 | g_total_loss: 3.5409
# Epoch [  400/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0000 | g_total_loss: 3.5896
# Saved image_samples/sample-000400-X-Y.png
# Saved image_samples/sample-000400-Y-X.png
# Epoch [  410/ 5000] | d_X_loss: 0.0061 | d_Y_loss: 0.0000 | g_total_loss: 3.7662
# Epoch [  420/ 5000] | d_X_loss: 0.0234 | d_Y_loss: 0.0000 | g_total_loss: 3.9115
# Epoch [  430/ 5000] | d_X_loss: 0.0224 | d_Y_loss: 0.0000 | g_total_loss: 3.7711
# Epoch [  440/ 5000] | d_X_loss: 0.0094 | d_Y_loss: 0.0001 | g_total_loss: 3.3786
# Epoch [  450/ 5000] | d_X_loss: 0.0188 | d_Y_loss: 0.0000 | g_total_loss: 3.8794
# Epoch [  460/ 5000] | d_X_loss: 0.0053 | d_Y_loss: 0.0000 | g_total_loss: 3.8634
# Epoch [  470/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0000 | g_total_loss: 3.7872
# Epoch [  480/ 5000] | d_X_loss: 0.0094 | d_Y_loss: 0.0001 | g_total_loss: 3.4239
# Epoch [  490/ 5000] | d_X_loss: 0.0596 | d_Y_loss: 0.0000 | g_total_loss: 3.2668
# Epoch [  500/ 5000] | d_X_loss: 0.0069 | d_Y_loss: 0.0000 | g_total_loss: 3.8912
# Saved image_samples/sample-000500-X-Y.png
# Saved image_samples/sample-000500-Y-X.png
# Epoch [  510/ 5000] | d_X_loss: 0.0904 | d_Y_loss: 0.0000 | g_total_loss: 3.7417
# Epoch [  520/ 5000] | d_X_loss: 0.0365 | d_Y_loss: 0.0000 | g_total_loss: 3.5079
# Epoch [  530/ 5000] | d_X_loss: 0.0172 | d_Y_loss: 0.0000 | g_total_loss: 3.4300
# Epoch [  540/ 5000] | d_X_loss: 0.0415 | d_Y_loss: 0.0000 | g_total_loss: 3.7257
# Epoch [  550/ 5000] | d_X_loss: 0.0139 | d_Y_loss: 0.0000 | g_total_loss: 3.5348
# Epoch [  560/ 5000] | d_X_loss: 0.0116 | d_Y_loss: 0.0000 | g_total_loss: 3.7421
# Epoch [  570/ 5000] | d_X_loss: 0.0165 | d_Y_loss: 0.0000 | g_total_loss: 3.4753
# Epoch [  580/ 5000] | d_X_loss: 0.0376 | d_Y_loss: 0.0000 | g_total_loss: 3.9537
# Epoch [  590/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 0.0000 | g_total_loss: 3.7878
# Epoch [  600/ 5000] | d_X_loss: 0.0126 | d_Y_loss: 0.0000 | g_total_loss: 3.4092
# Saved image_samples/sample-000600-X-Y.png
# Saved image_samples/sample-000600-Y-X.png
# Epoch [  610/ 5000] | d_X_loss: 0.0226 | d_Y_loss: 0.0000 | g_total_loss: 3.9460
# Epoch [  620/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0000 | g_total_loss: 3.6582
# Epoch [  630/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 0.0000 | g_total_loss: 3.6283
# Epoch [  640/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0000 | g_total_loss: 3.6983
# Epoch [  650/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 0.0000 | g_total_loss: 3.7953
# Epoch [  660/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0000 | g_total_loss: 4.1047
# Epoch [  670/ 5000] | d_X_loss: 0.0107 | d_Y_loss: 0.0000 | g_total_loss: 3.8583
# Epoch [  680/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0000 | g_total_loss: 3.6179
# Epoch [  690/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0000 | g_total_loss: 3.8332
# Epoch [  700/ 5000] | d_X_loss: 0.0037 | d_Y_loss: 0.0000 | g_total_loss: 3.7044
# Saved image_samples/sample-000700-X-Y.png
# Saved image_samples/sample-000700-Y-X.png
# Epoch [  710/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0000 | g_total_loss: 3.4039
# Epoch [  720/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0000 | g_total_loss: 3.5264
# Epoch [  730/ 5000] | d_X_loss: 0.0111 | d_Y_loss: 0.0000 | g_total_loss: 3.5910
# Epoch [  740/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0000 | g_total_loss: 3.4316
# Epoch [  750/ 5000] | d_X_loss: 0.0185 | d_Y_loss: 0.0000 | g_total_loss: 3.6408
# Epoch [  760/ 5000] | d_X_loss: 0.0084 | d_Y_loss: 0.0000 | g_total_loss: 3.4996
# Epoch [  770/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0002 | g_total_loss: 3.5540
# Epoch [  780/ 5000] | d_X_loss: 0.0036 | d_Y_loss: 0.0000 | g_total_loss: 3.6302
# Epoch [  790/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0000 | g_total_loss: 3.5912
# Epoch [  800/ 5000] | d_X_loss: 0.0507 | d_Y_loss: 0.0000 | g_total_loss: 3.6126
# Saved image_samples/sample-000800-X-Y.png
# Saved image_samples/sample-000800-Y-X.png
# Epoch [  810/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0000 | g_total_loss: 3.7483
# Epoch [  820/ 5000] | d_X_loss: 0.0484 | d_Y_loss: 0.0001 | g_total_loss: 3.5813
# Epoch [  830/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0000 | g_total_loss: 3.5153
# Epoch [  840/ 5000] | d_X_loss: 0.2352 | d_Y_loss: 0.0000 | g_total_loss: 3.5877
# Epoch [  850/ 5000] | d_X_loss: 0.0120 | d_Y_loss: 0.0000 | g_total_loss: 3.5907
# Epoch [  860/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0000 | g_total_loss: 3.4513
# Epoch [  870/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.0000 | g_total_loss: 3.5873
# Epoch [  880/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 0.0000 | g_total_loss: 3.8875
# Epoch [  890/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.5670
# Epoch [  900/ 5000] | d_X_loss: 0.0128 | d_Y_loss: 0.0000 | g_total_loss: 3.4162
# Saved image_samples/sample-000900-X-Y.png
# Saved image_samples/sample-000900-Y-X.png
# Epoch [  910/ 5000] | d_X_loss: 0.1641 | d_Y_loss: 0.0001 | g_total_loss: 3.5504
# Epoch [  920/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0000 | g_total_loss: 3.4689
# Epoch [  930/ 5000] | d_X_loss: 0.0080 | d_Y_loss: 0.0000 | g_total_loss: 3.8133
# Epoch [  940/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 0.0000 | g_total_loss: 3.6088
# Epoch [  950/ 5000] | d_X_loss: 0.6744 | d_Y_loss: 0.0000 | g_total_loss: 3.5024
# Epoch [  960/ 5000] | d_X_loss: 0.0560 | d_Y_loss: 0.0000 | g_total_loss: 3.3731
# Epoch [  970/ 5000] | d_X_loss: 0.0120 | d_Y_loss: 0.0000 | g_total_loss: 4.1076
# Epoch [  980/ 5000] | d_X_loss: 0.0224 | d_Y_loss: 0.0000 | g_total_loss: 3.5233
# Epoch [  990/ 5000] | d_X_loss: 0.0051 | d_Y_loss: 0.0000 | g_total_loss: 3.5460
# Epoch [ 1000/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0000 | g_total_loss: 3.6651
# Saved image_samples/sample-001000-X-Y.png
# Saved image_samples/sample-001000-Y-X.png
# Epoch [ 1010/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0000 | g_total_loss: 3.4234
# Epoch [ 1020/ 5000] | d_X_loss: 0.0167 | d_Y_loss: 0.0000 | g_total_loss: 3.7501
# Epoch [ 1030/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.0001 | g_total_loss: 3.6563
# Epoch [ 1040/ 5000] | d_X_loss: 0.0036 | d_Y_loss: 0.5202 | g_total_loss: 2.9044
# Epoch [ 1050/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 0.6311 | g_total_loss: 3.5211
# Epoch [ 1060/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 0.6264 | g_total_loss: 3.2983
# Epoch [ 1070/ 5000] | d_X_loss: 0.0155 | d_Y_loss: 0.0070 | g_total_loss: 3.4401
# Epoch [ 1080/ 5000] | d_X_loss: 0.0106 | d_Y_loss: 0.0160 | g_total_loss: 3.6989
# Epoch [ 1090/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.7998 | g_total_loss: 3.6861
# Epoch [ 1100/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0015 | g_total_loss: 3.5766
# Saved image_samples/sample-001100-X-Y.png
# Saved image_samples/sample-001100-Y-X.png
# Epoch [ 1110/ 5000] | d_X_loss: 0.0155 | d_Y_loss: 0.0035 | g_total_loss: 3.5472
# Epoch [ 1120/ 5000] | d_X_loss: 0.0031 | d_Y_loss: 0.0000 | g_total_loss: 3.5041
# Epoch [ 1130/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0000 | g_total_loss: 3.6627
# Epoch [ 1140/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0000 | g_total_loss: 3.6152
# Epoch [ 1150/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 0.0111 | g_total_loss: 3.5246
# Epoch [ 1160/ 5000] | d_X_loss: 0.0097 | d_Y_loss: 0.0000 | g_total_loss: 3.6460
# Epoch [ 1170/ 5000] | d_X_loss: 0.0980 | d_Y_loss: 0.0000 | g_total_loss: 3.1424
# Epoch [ 1180/ 5000] | d_X_loss: 0.0519 | d_Y_loss: 0.0000 | g_total_loss: 3.8393
# Epoch [ 1190/ 5000] | d_X_loss: 0.0124 | d_Y_loss: 0.0073 | g_total_loss: 3.5843
# Epoch [ 1200/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0007 | g_total_loss: 3.6145
# Saved image_samples/sample-001200-X-Y.png
# Saved image_samples/sample-001200-Y-X.png
# Epoch [ 1210/ 5000] | d_X_loss: 0.0090 | d_Y_loss: 0.0000 | g_total_loss: 3.7277
# Epoch [ 1220/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0000 | g_total_loss: 3.5154
# Epoch [ 1230/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0111 | g_total_loss: 3.5291
# Epoch [ 1240/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0001 | g_total_loss: 3.7533
# Epoch [ 1250/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0000 | g_total_loss: 3.4494
# Epoch [ 1260/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 0.0000 | g_total_loss: 3.4251
# Epoch [ 1270/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0000 | g_total_loss: 3.6796
# Epoch [ 1280/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.0000 | g_total_loss: 3.6014
# Epoch [ 1290/ 5000] | d_X_loss: 0.1130 | d_Y_loss: 0.0000 | g_total_loss: 3.6094
# Epoch [ 1300/ 5000] | d_X_loss: 0.0202 | d_Y_loss: 1.0000 | g_total_loss: 3.4507
# Saved image_samples/sample-001300-X-Y.png
# Saved image_samples/sample-001300-Y-X.png
# Epoch [ 1310/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 1.0000 | g_total_loss: 3.5961
# Epoch [ 1320/ 5000] | d_X_loss: 0.6512 | d_Y_loss: 1.0000 | g_total_loss: 3.7753
# Epoch [ 1330/ 5000] | d_X_loss: 0.0706 | d_Y_loss: 1.0000 | g_total_loss: 3.7195
# Epoch [ 1340/ 5000] | d_X_loss: 0.0155 | d_Y_loss: 1.0000 | g_total_loss: 3.4721
# Epoch [ 1350/ 5000] | d_X_loss: 0.0287 | d_Y_loss: 1.0000 | g_total_loss: 3.7556
# Epoch [ 1360/ 5000] | d_X_loss: 0.0219 | d_Y_loss: 1.0000 | g_total_loss: 3.3307
# Epoch [ 1370/ 5000] | d_X_loss: 0.0667 | d_Y_loss: 1.0000 | g_total_loss: 3.5841
# Epoch [ 1380/ 5000] | d_X_loss: 0.0093 | d_Y_loss: 1.0000 | g_total_loss: 3.4310
# Epoch [ 1390/ 5000] | d_X_loss: 0.0124 | d_Y_loss: 1.0000 | g_total_loss: 3.5368
# Epoch [ 1400/ 5000] | d_X_loss: 0.1301 | d_Y_loss: 1.0000 | g_total_loss: 3.4815
# Saved image_samples/sample-001400-X-Y.png
# Saved image_samples/sample-001400-Y-X.png
# Epoch [ 1410/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.6463
# Epoch [ 1420/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 1.0000 | g_total_loss: 3.4199
# Epoch [ 1430/ 5000] | d_X_loss: 0.0141 | d_Y_loss: 1.0000 | g_total_loss: 3.3674
# Epoch [ 1440/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 1.0000 | g_total_loss: 3.7276
# Epoch [ 1450/ 5000] | d_X_loss: 0.0270 | d_Y_loss: 1.0000 | g_total_loss: 3.5925
# Epoch [ 1460/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.5877
# Epoch [ 1470/ 5000] | d_X_loss: 0.0209 | d_Y_loss: 1.0000 | g_total_loss: 3.5918
# Epoch [ 1480/ 5000] | d_X_loss: 0.0142 | d_Y_loss: 1.0000 | g_total_loss: 3.5617
# Epoch [ 1490/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 1.0000 | g_total_loss: 3.3680
# Epoch [ 1500/ 5000] | d_X_loss: 0.0114 | d_Y_loss: 1.0000 | g_total_loss: 3.4807
# Saved image_samples/sample-001500-X-Y.png
# Saved image_samples/sample-001500-Y-X.png
# Epoch [ 1510/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 1.0000 | g_total_loss: 3.3908
# Epoch [ 1520/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 1.0000 | g_total_loss: 3.6616
# Epoch [ 1530/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 1.0000 | g_total_loss: 3.4962
# Epoch [ 1540/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.6822
# Epoch [ 1550/ 5000] | d_X_loss: 0.0038 | d_Y_loss: 1.0000 | g_total_loss: 3.5699
# Epoch [ 1560/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.3875
# Epoch [ 1570/ 5000] | d_X_loss: 0.0098 | d_Y_loss: 1.0000 | g_total_loss: 3.9849
# Epoch [ 1580/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 1.0000 | g_total_loss: 3.6189
# Epoch [ 1590/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.7420
# Epoch [ 1600/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 1.0000 | g_total_loss: 3.5427
# Saved image_samples/sample-001600-X-Y.png
# Saved image_samples/sample-001600-Y-X.png
# Epoch [ 1610/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.6847
# Epoch [ 1620/ 5000] | d_X_loss: 0.0031 | d_Y_loss: 1.0000 | g_total_loss: 3.5888
# Epoch [ 1630/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 1.0000 | g_total_loss: 3.7046
# Epoch [ 1640/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 1.0000 | g_total_loss: 3.7458
# Epoch [ 1650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7064
# Epoch [ 1660/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 1.0000 | g_total_loss: 3.8183
# Epoch [ 1670/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.5990
# Epoch [ 1680/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.7161
# Epoch [ 1690/ 5000] | d_X_loss: 0.0051 | d_Y_loss: 1.0000 | g_total_loss: 3.7592
# Epoch [ 1700/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.5304
# Saved image_samples/sample-001700-X-Y.png
# Saved image_samples/sample-001700-Y-X.png
# Epoch [ 1710/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.4956
# Epoch [ 1720/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5903
# Epoch [ 1730/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 1.0000 | g_total_loss: 3.6613
# Epoch [ 1740/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5013
# Epoch [ 1750/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 1.0000 | g_total_loss: 3.5572
# Epoch [ 1760/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 1.0000 | g_total_loss: 3.4973
# Epoch [ 1770/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.3953
# Epoch [ 1780/ 5000] | d_X_loss: 0.0072 | d_Y_loss: 1.0000 | g_total_loss: 3.4368
# Epoch [ 1790/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 1.0000 | g_total_loss: 3.3040
# Epoch [ 1800/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.4347
# Saved image_samples/sample-001800-X-Y.png
# Saved image_samples/sample-001800-Y-X.png
# Epoch [ 1810/ 5000] | d_X_loss: 0.0065 | d_Y_loss: 1.0000 | g_total_loss: 3.4247
# Epoch [ 1820/ 5000] | d_X_loss: 0.0040 | d_Y_loss: 1.0000 | g_total_loss: 3.6591
# Epoch [ 1830/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 1.0000 | g_total_loss: 3.5412
# Epoch [ 1840/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.2530
# Epoch [ 1850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.5135
# Epoch [ 1860/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.3879
# Epoch [ 1870/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.5284
# Epoch [ 1880/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.4069
# Epoch [ 1890/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 1.0000 | g_total_loss: 3.4560
# Epoch [ 1900/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 1.0000 | g_total_loss: 3.4539
# Saved image_samples/sample-001900-X-Y.png
# Saved image_samples/sample-001900-Y-X.png
# Epoch [ 1910/ 5000] | d_X_loss: 0.0064 | d_Y_loss: 1.0000 | g_total_loss: 3.7131
# Epoch [ 1920/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.4278
# Epoch [ 1930/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 1.0000 | g_total_loss: 3.6082
# Epoch [ 1940/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 1.0000 | g_total_loss: 3.3974
# Epoch [ 1950/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.2419
# Epoch [ 1960/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5415
# Epoch [ 1970/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.3604
# Epoch [ 1980/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 1.0000 | g_total_loss: 3.4589
# Epoch [ 1990/ 5000] | d_X_loss: 0.0295 | d_Y_loss: 1.0000 | g_total_loss: 3.3663
# Epoch [ 2000/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.4898
# Saved image_samples/sample-002000-X-Y.png
# Saved image_samples/sample-002000-Y-X.png
# Epoch [ 2010/ 5000] | d_X_loss: 0.0083 | d_Y_loss: 1.0000 | g_total_loss: 3.5869
# Epoch [ 2020/ 5000] | d_X_loss: 0.3394 | d_Y_loss: 1.0000 | g_total_loss: 2.5066
# Epoch [ 2030/ 5000] | d_X_loss: 0.0142 | d_Y_loss: 1.0000 | g_total_loss: 3.4790
# Epoch [ 2040/ 5000] | d_X_loss: 0.0134 | d_Y_loss: 1.0000 | g_total_loss: 3.7067
# Epoch [ 2050/ 5000] | d_X_loss: 0.0129 | d_Y_loss: 1.0000 | g_total_loss: 3.3367
# Epoch [ 2060/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 1.0000 | g_total_loss: 3.5929
# Epoch [ 2070/ 5000] | d_X_loss: 0.0301 | d_Y_loss: 1.0000 | g_total_loss: 3.5547
# Epoch [ 2080/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.4378
# Epoch [ 2090/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 1.0000 | g_total_loss: 3.8874
# Epoch [ 2100/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.7671
# Saved image_samples/sample-002100-X-Y.png
# Saved image_samples/sample-002100-Y-X.png
# Epoch [ 2110/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.4866
# Epoch [ 2120/ 5000] | d_X_loss: 0.2192 | d_Y_loss: 1.0000 | g_total_loss: 3.4034
# Epoch [ 2130/ 5000] | d_X_loss: 0.0499 | d_Y_loss: 1.0000 | g_total_loss: 3.4017
# Epoch [ 2140/ 5000] | d_X_loss: 0.0774 | d_Y_loss: 1.0000 | g_total_loss: 3.6399
# Epoch [ 2150/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 1.0000 | g_total_loss: 3.5550
# Epoch [ 2160/ 5000] | d_X_loss: 0.0012 | d_Y_loss: 1.0000 | g_total_loss: 3.5615
# Epoch [ 2170/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 1.0000 | g_total_loss: 3.6654
# Epoch [ 2180/ 5000] | d_X_loss: 0.0124 | d_Y_loss: 1.0000 | g_total_loss: 3.5264
# Epoch [ 2190/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.4470
# Epoch [ 2200/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 1.0000 | g_total_loss: 3.4323
# Saved image_samples/sample-002200-X-Y.png
# Saved image_samples/sample-002200-Y-X.png
# Epoch [ 2210/ 5000] | d_X_loss: 0.0630 | d_Y_loss: 1.0000 | g_total_loss: 3.6113
# Epoch [ 2220/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.3245
# Epoch [ 2230/ 5000] | d_X_loss: 0.0350 | d_Y_loss: 1.0000 | g_total_loss: 3.5710
# Epoch [ 2240/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.3774
# Epoch [ 2250/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 1.0000 | g_total_loss: 3.3730
# Epoch [ 2260/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 1.0000 | g_total_loss: 3.8998
# Epoch [ 2270/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.3288
# Epoch [ 2280/ 5000] | d_X_loss: 0.0106 | d_Y_loss: 1.0000 | g_total_loss: 3.6325
# Epoch [ 2290/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.5716
# Epoch [ 2300/ 5000] | d_X_loss: 0.0306 | d_Y_loss: 1.0000 | g_total_loss: 3.3900
# Saved image_samples/sample-002300-X-Y.png
# Saved image_samples/sample-002300-Y-X.png
# Epoch [ 2310/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.4113
# Epoch [ 2320/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 1.0000 | g_total_loss: 3.6177
# Epoch [ 2330/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5751
# Epoch [ 2340/ 5000] | d_X_loss: 0.0283 | d_Y_loss: 1.0000 | g_total_loss: 3.4985
# Epoch [ 2350/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.4977
# Epoch [ 2360/ 5000] | d_X_loss: 0.0045 | d_Y_loss: 1.0000 | g_total_loss: 3.4043
# Epoch [ 2370/ 5000] | d_X_loss: 0.0110 | d_Y_loss: 1.0000 | g_total_loss: 3.3442
# Epoch [ 2380/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 1.0000 | g_total_loss: 3.4513
# Epoch [ 2390/ 5000] | d_X_loss: 0.3894 | d_Y_loss: 1.0000 | g_total_loss: 3.5002
# Epoch [ 2400/ 5000] | d_X_loss: 0.0160 | d_Y_loss: 1.0000 | g_total_loss: 3.5154
# Saved image_samples/sample-002400-X-Y.png
# Saved image_samples/sample-002400-Y-X.png
# Epoch [ 2410/ 5000] | d_X_loss: 0.0192 | d_Y_loss: 1.0000 | g_total_loss: 3.5009
# Epoch [ 2420/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 1.0000 | g_total_loss: 3.3399
# Epoch [ 2430/ 5000] | d_X_loss: 0.0123 | d_Y_loss: 1.0000 | g_total_loss: 3.7808
# Epoch [ 2440/ 5000] | d_X_loss: 0.0035 | d_Y_loss: 1.0000 | g_total_loss: 3.4199
# Epoch [ 2450/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 1.0000 | g_total_loss: 3.4549
# Epoch [ 2460/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 1.0000 | g_total_loss: 3.4900
# Epoch [ 2470/ 5000] | d_X_loss: 0.0431 | d_Y_loss: 1.0000 | g_total_loss: 3.2672
# Epoch [ 2480/ 5000] | d_X_loss: 0.0033 | d_Y_loss: 1.0000 | g_total_loss: 3.5320
# Epoch [ 2490/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.6539
# Epoch [ 2500/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 1.0000 | g_total_loss: 3.2447
# Saved image_samples/sample-002500-X-Y.png
# Saved image_samples/sample-002500-Y-X.png
# Epoch [ 2510/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 1.0000 | g_total_loss: 3.5781
# Epoch [ 2520/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.4410
# Epoch [ 2530/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 1.0000 | g_total_loss: 3.6174
# Epoch [ 2540/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.4626
# Epoch [ 2550/ 5000] | d_X_loss: 0.0115 | d_Y_loss: 1.0000 | g_total_loss: 3.4710
# Epoch [ 2560/ 5000] | d_X_loss: 0.0097 | d_Y_loss: 1.0000 | g_total_loss: 3.5277
# Epoch [ 2570/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 1.0000 | g_total_loss: 3.2794
# Epoch [ 2580/ 5000] | d_X_loss: 0.0141 | d_Y_loss: 1.0000 | g_total_loss: 3.4716
# Epoch [ 2590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.7972
# Epoch [ 2600/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 1.0000 | g_total_loss: 3.3066
# Saved image_samples/sample-002600-X-Y.png
# Saved image_samples/sample-002600-Y-X.png
# Epoch [ 2610/ 5000] | d_X_loss: 0.0325 | d_Y_loss: 1.0000 | g_total_loss: 3.2896
# Epoch [ 2620/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.4190
# Epoch [ 2630/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.6940
# Epoch [ 2640/ 5000] | d_X_loss: 0.0690 | d_Y_loss: 1.0000 | g_total_loss: 3.5785
# Epoch [ 2650/ 5000] | d_X_loss: 0.0268 | d_Y_loss: 1.0000 | g_total_loss: 3.6462
# Epoch [ 2660/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 1.0000 | g_total_loss: 3.2753
# Epoch [ 2670/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.4873
# Epoch [ 2680/ 5000] | d_X_loss: 0.0409 | d_Y_loss: 1.0000 | g_total_loss: 3.6199
# Epoch [ 2690/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.1982
# Epoch [ 2700/ 5000] | d_X_loss: 0.0025 | d_Y_loss: 1.0000 | g_total_loss: 3.3110
# Saved image_samples/sample-002700-X-Y.png
# Saved image_samples/sample-002700-Y-X.png
# Epoch [ 2710/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.4143
# Epoch [ 2720/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.6510
# Epoch [ 2730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.6162
# Epoch [ 2740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 1.0000 | g_total_loss: 3.4651
# Epoch [ 2750/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.4412
# Epoch [ 2760/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 1.0000 | g_total_loss: 3.4084
# Epoch [ 2770/ 5000] | d_X_loss: 0.0061 | d_Y_loss: 1.0000 | g_total_loss: 3.4899
# Epoch [ 2780/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.3250
# Epoch [ 2790/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 1.0000 | g_total_loss: 3.4747
# Epoch [ 2800/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 1.0000 | g_total_loss: 3.5252
# Saved image_samples/sample-002800-X-Y.png
# Saved image_samples/sample-002800-Y-X.png
# Epoch [ 2810/ 5000] | d_X_loss: 0.0043 | d_Y_loss: 1.0000 | g_total_loss: 3.2979
# Epoch [ 2820/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.2582
# Epoch [ 2830/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.4100
# Epoch [ 2840/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 1.0000 | g_total_loss: 3.4173
# Epoch [ 2850/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 1.0000 | g_total_loss: 3.2864
# Epoch [ 2860/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.3431
# Epoch [ 2870/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.5313
# Epoch [ 2880/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 1.0000 | g_total_loss: 3.4313
# Epoch [ 2890/ 5000] | d_X_loss: 0.0098 | d_Y_loss: 1.0000 | g_total_loss: 3.2470
# Epoch [ 2900/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.4247
# Saved image_samples/sample-002900-X-Y.png
# Saved image_samples/sample-002900-Y-X.png
# Epoch [ 2910/ 5000] | d_X_loss: 0.0036 | d_Y_loss: 1.0000 | g_total_loss: 3.6136
# Epoch [ 2920/ 5000] | d_X_loss: 0.1615 | d_Y_loss: 1.0000 | g_total_loss: 3.3799
# Epoch [ 2930/ 5000] | d_X_loss: 0.0092 | d_Y_loss: 1.0000 | g_total_loss: 3.5068
# Epoch [ 2940/ 5000] | d_X_loss: 0.0054 | d_Y_loss: 1.0000 | g_total_loss: 3.5170
# Epoch [ 2950/ 5000] | d_X_loss: 0.0010 | d_Y_loss: 1.0000 | g_total_loss: 3.3376
# Epoch [ 2960/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.4871
# Epoch [ 2970/ 5000] | d_X_loss: 0.0246 | d_Y_loss: 1.0000 | g_total_loss: 3.5463
# Epoch [ 2980/ 5000] | d_X_loss: 0.0021 | d_Y_loss: 1.0000 | g_total_loss: 3.4289
# Epoch [ 2990/ 5000] | d_X_loss: 0.0215 | d_Y_loss: 1.0000 | g_total_loss: 3.2987
# Epoch [ 3000/ 5000] | d_X_loss: 0.0138 | d_Y_loss: 1.0000 | g_total_loss: 3.6099
# Saved image_samples/sample-003000-X-Y.png
# Saved image_samples/sample-003000-Y-X.png
# Epoch [ 3010/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.3419
# Epoch [ 3020/ 5000] | d_X_loss: 0.1852 | d_Y_loss: 1.0000 | g_total_loss: 3.4745
# Epoch [ 3030/ 5000] | d_X_loss: 0.0081 | d_Y_loss: 1.0000 | g_total_loss: 3.2563
# Epoch [ 3040/ 5000] | d_X_loss: 0.0092 | d_Y_loss: 1.0000 | g_total_loss: 3.5033
# Epoch [ 3050/ 5000] | d_X_loss: 0.0096 | d_Y_loss: 1.0000 | g_total_loss: 3.4325
# Epoch [ 3060/ 5000] | d_X_loss: 0.0182 | d_Y_loss: 1.0000 | g_total_loss: 3.4297
# Epoch [ 3070/ 5000] | d_X_loss: 0.0948 | d_Y_loss: 1.0000 | g_total_loss: 3.2745
# Epoch [ 3080/ 5000] | d_X_loss: 0.0335 | d_Y_loss: 1.0000 | g_total_loss: 3.4541
# Epoch [ 3090/ 5000] | d_X_loss: 0.0029 | d_Y_loss: 1.0000 | g_total_loss: 3.6269
# Epoch [ 3100/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 1.0000 | g_total_loss: 3.4906
# Saved image_samples/sample-003100-X-Y.png
# Saved image_samples/sample-003100-Y-X.png
# Epoch [ 3110/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 1.0000 | g_total_loss: 3.3595
# Epoch [ 3120/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 1.0000 | g_total_loss: 3.5182
# Epoch [ 3130/ 5000] | d_X_loss: 0.0047 | d_Y_loss: 1.0000 | g_total_loss: 3.3899
# Epoch [ 3140/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.3155
# Epoch [ 3150/ 5000] | d_X_loss: 0.0084 | d_Y_loss: 1.0000 | g_total_loss: 3.2936
# Epoch [ 3160/ 5000] | d_X_loss: 0.0040 | d_Y_loss: 1.0000 | g_total_loss: 3.5097
# Epoch [ 3170/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 1.0000 | g_total_loss: 3.3384
# Epoch [ 3180/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.6263
# Epoch [ 3190/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 1.0000 | g_total_loss: 3.4637
# Epoch [ 3200/ 5000] | d_X_loss: 0.0048 | d_Y_loss: 1.0000 | g_total_loss: 3.3082
# Saved image_samples/sample-003200-X-Y.png
# Saved image_samples/sample-003200-Y-X.png
# Epoch [ 3210/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 1.0000 | g_total_loss: 3.4600
# Epoch [ 3220/ 5000] | d_X_loss: 0.0073 | d_Y_loss: 1.0000 | g_total_loss: 3.3521
# Epoch [ 3230/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 1.0000 | g_total_loss: 3.5061
# Epoch [ 3240/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 1.0000 | g_total_loss: 3.1798
# Epoch [ 3250/ 5000] | d_X_loss: 0.0336 | d_Y_loss: 1.0000 | g_total_loss: 3.6582
# Epoch [ 3260/ 5000] | d_X_loss: 0.0045 | d_Y_loss: 1.0000 | g_total_loss: 3.2528
# Epoch [ 3270/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.5922
# Epoch [ 3280/ 5000] | d_X_loss: 0.0026 | d_Y_loss: 1.0000 | g_total_loss: 3.4738
# Epoch [ 3290/ 5000] | d_X_loss: 0.0017 | d_Y_loss: 1.0000 | g_total_loss: 3.5641
# Epoch [ 3300/ 5000] | d_X_loss: 0.0043 | d_Y_loss: 1.0000 | g_total_loss: 3.3287
# Saved image_samples/sample-003300-X-Y.png
# Saved image_samples/sample-003300-Y-X.png
# Epoch [ 3310/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 1.0000 | g_total_loss: 3.3037
# Epoch [ 3320/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 1.0000 | g_total_loss: 3.3891
# Epoch [ 3330/ 5000] | d_X_loss: 0.0180 | d_Y_loss: 0.0789 | g_total_loss: 2.9651
# Epoch [ 3340/ 5000] | d_X_loss: 0.0038 | d_Y_loss: 0.8700 | g_total_loss: 3.6474
# Epoch [ 3350/ 5000] | d_X_loss: 0.0312 | d_Y_loss: 0.6953 | g_total_loss: 3.4143
# Epoch [ 3360/ 5000] | d_X_loss: 0.0015 | d_Y_loss: 0.6321 | g_total_loss: 3.4971
# Epoch [ 3370/ 5000] | d_X_loss: 0.0070 | d_Y_loss: 0.3141 | g_total_loss: 3.4121
# Epoch [ 3380/ 5000] | d_X_loss: 0.0040 | d_Y_loss: 0.6190 | g_total_loss: 3.4292
# Epoch [ 3390/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0256 | g_total_loss: 3.3988
# Epoch [ 3400/ 5000] | d_X_loss: 0.0122 | d_Y_loss: 0.2806 | g_total_loss: 2.9251
# Saved image_samples/sample-003400-X-Y.png
# Saved image_samples/sample-003400-Y-X.png
# Epoch [ 3410/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0389 | g_total_loss: 3.7720
# Epoch [ 3420/ 5000] | d_X_loss: 0.0235 | d_Y_loss: 0.0023 | g_total_loss: 3.5926
# Epoch [ 3430/ 5000] | d_X_loss: 0.0153 | d_Y_loss: 0.0035 | g_total_loss: 3.4567
# Epoch [ 3440/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0010 | g_total_loss: 3.7946
# Epoch [ 3450/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0002 | g_total_loss: 3.5485
# Epoch [ 3460/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0001 | g_total_loss: 3.5019
# Epoch [ 3470/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4103
# Epoch [ 3480/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0001 | g_total_loss: 3.3703
# Epoch [ 3490/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0001 | g_total_loss: 3.4586
# Epoch [ 3500/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0000 | g_total_loss: 3.2878
# Saved image_samples/sample-003500-X-Y.png
# Saved image_samples/sample-003500-Y-X.png
# Epoch [ 3510/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.1903
# Epoch [ 3520/ 5000] | d_X_loss: 0.0252 | d_Y_loss: 0.0001 | g_total_loss: 3.4518
# Epoch [ 3530/ 5000] | d_X_loss: 0.0171 | d_Y_loss: 0.0000 | g_total_loss: 3.4535
# Epoch [ 3540/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 3.3949
# Epoch [ 3550/ 5000] | d_X_loss: 0.0120 | d_Y_loss: 0.0001 | g_total_loss: 3.3533
# Epoch [ 3560/ 5000] | d_X_loss: 0.0063 | d_Y_loss: 0.0000 | g_total_loss: 3.3918
# Epoch [ 3570/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0000 | g_total_loss: 3.5307
# Epoch [ 3580/ 5000] | d_X_loss: 0.0112 | d_Y_loss: 0.9979 | g_total_loss: 3.3057
# Epoch [ 3590/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.9699 | g_total_loss: 3.3136
# Epoch [ 3600/ 5000] | d_X_loss: 0.0107 | d_Y_loss: 0.0613 | g_total_loss: 3.5503
# Saved image_samples/sample-003600-X-Y.png
# Saved image_samples/sample-003600-Y-X.png
# Epoch [ 3610/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.9218 | g_total_loss: 3.4294
# Epoch [ 3620/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0184 | g_total_loss: 3.5513
# Epoch [ 3630/ 5000] | d_X_loss: 0.0020 | d_Y_loss: 0.0004 | g_total_loss: 3.6307
# Epoch [ 3640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0006 | g_total_loss: 3.7588
# Epoch [ 3650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0007 | g_total_loss: 3.8408
# Epoch [ 3660/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0004 | g_total_loss: 3.5238
# Epoch [ 3670/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 3.4296
# Epoch [ 3680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5127
# Epoch [ 3690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0050 | g_total_loss: 3.4723
# Epoch [ 3700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7075
# Saved image_samples/sample-003700-X-Y.png
# Saved image_samples/sample-003700-Y-X.png
# Epoch [ 3710/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3987
# Epoch [ 3720/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5873
# Epoch [ 3730/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 3.6806
# Epoch [ 3740/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 3.4700
# Epoch [ 3750/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.2852
# Epoch [ 3760/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.5005
# Epoch [ 3770/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4480
# Epoch [ 3780/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4864
# Epoch [ 3790/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0005 | g_total_loss: 3.5762
# Epoch [ 3800/ 5000] | d_X_loss: 0.0027 | d_Y_loss: 0.7854 | g_total_loss: 3.2368
# Saved image_samples/sample-003800-X-Y.png
# Saved image_samples/sample-003800-Y-X.png
# Epoch [ 3810/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0008 | g_total_loss: 3.5876
# Epoch [ 3820/ 5000] | d_X_loss: 0.0025 | d_Y_loss: 0.0143 | g_total_loss: 3.4061
# Epoch [ 3830/ 5000] | d_X_loss: 0.0016 | d_Y_loss: 0.0331 | g_total_loss: 3.6050
# Epoch [ 3840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6550
# Epoch [ 3850/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0005 | g_total_loss: 3.5500
# Epoch [ 3860/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0005 | g_total_loss: 3.3006
# Epoch [ 3870/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0119 | g_total_loss: 3.2388
# Epoch [ 3880/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0010 | g_total_loss: 3.4758
# Epoch [ 3890/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0471 | g_total_loss: 3.4515
# Epoch [ 3900/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.0002 | g_total_loss: 3.6874
# Saved image_samples/sample-003900-X-Y.png
# Saved image_samples/sample-003900-Y-X.png
# Epoch [ 3910/ 5000] | d_X_loss: 0.0083 | d_Y_loss: 0.0000 | g_total_loss: 3.5852
# Epoch [ 3920/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4577
# Epoch [ 3930/ 5000] | d_X_loss: 0.0063 | d_Y_loss: 0.0009 | g_total_loss: 3.3685
# Epoch [ 3940/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0006 | g_total_loss: 3.6925
# Epoch [ 3950/ 5000] | d_X_loss: 0.0110 | d_Y_loss: 0.0001 | g_total_loss: 3.4996
# Epoch [ 3960/ 5000] | d_X_loss: 0.0530 | d_Y_loss: 0.0000 | g_total_loss: 3.2538
# Epoch [ 3970/ 5000] | d_X_loss: 0.0170 | d_Y_loss: 0.0000 | g_total_loss: 3.5035
# Epoch [ 3980/ 5000] | d_X_loss: 0.0082 | d_Y_loss: 0.0000 | g_total_loss: 3.3331
# Epoch [ 3990/ 5000] | d_X_loss: 0.0056 | d_Y_loss: 0.0001 | g_total_loss: 3.2888
# Epoch [ 4000/ 5000] | d_X_loss: 0.0492 | d_Y_loss: 0.0000 | g_total_loss: 3.5706
# Saved image_samples/sample-004000-X-Y.png
# Saved image_samples/sample-004000-Y-X.png
# Epoch [ 4010/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.9651 | g_total_loss: 3.3426
# Epoch [ 4020/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0031 | g_total_loss: 3.2216
# Epoch [ 4030/ 5000] | d_X_loss: 0.0013 | d_Y_loss: 0.8819 | g_total_loss: 3.3837
# Epoch [ 4040/ 5000] | d_X_loss: 0.0014 | d_Y_loss: 0.0023 | g_total_loss: 3.4231
# Epoch [ 4050/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.2034
# Epoch [ 4060/ 5000] | d_X_loss: 0.0018 | d_Y_loss: 0.0001 | g_total_loss: 3.4073
# Epoch [ 4070/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0003 | g_total_loss: 3.5494
# Epoch [ 4080/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0001 | g_total_loss: 3.3643
# Epoch [ 4090/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5104
# Epoch [ 4100/ 5000] | d_X_loss: 0.0008 | d_Y_loss: 0.0002 | g_total_loss: 3.5001
# Saved image_samples/sample-004100-X-Y.png
# Saved image_samples/sample-004100-Y-X.png
# Epoch [ 4110/ 5000] | d_X_loss: 0.0037 | d_Y_loss: 0.0001 | g_total_loss: 3.6304
# Epoch [ 4120/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 0.0003 | g_total_loss: 3.6322
# Epoch [ 4130/ 5000] | d_X_loss: 0.0025 | d_Y_loss: 0.0001 | g_total_loss: 3.2043
# Epoch [ 4140/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1700
# Epoch [ 4150/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3491
# Epoch [ 4160/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2830
# Epoch [ 4170/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.1604
# Epoch [ 4180/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 3.2597
# Epoch [ 4190/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3212
# Epoch [ 4200/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4006
# Saved image_samples/sample-004200-X-Y.png
# Saved image_samples/sample-004200-Y-X.png
# Epoch [ 4210/ 5000] | d_X_loss: 0.0101 | d_Y_loss: 0.0000 | g_total_loss: 3.3448
# Epoch [ 4220/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.1884
# Epoch [ 4230/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.6244
# Epoch [ 4240/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.2474
# Epoch [ 4250/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.3825
# Epoch [ 4260/ 5000] | d_X_loss: 0.0011 | d_Y_loss: 0.0000 | g_total_loss: 3.0944
# Epoch [ 4270/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2991
# Epoch [ 4280/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1668
# Epoch [ 4290/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.2692
# Epoch [ 4300/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3646
# Saved image_samples/sample-004300-X-Y.png
# Saved image_samples/sample-004300-Y-X.png
# Epoch [ 4310/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0000 | g_total_loss: 3.4983
# Epoch [ 4320/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6112
# Epoch [ 4330/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6265
# Epoch [ 4340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.4792
# Epoch [ 4350/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0000 | g_total_loss: 3.7019
# Epoch [ 4360/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3904
# Epoch [ 4370/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2185
# Epoch [ 4380/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0008 | g_total_loss: 3.3992
# Epoch [ 4390/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3508
# Epoch [ 4400/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 3.4009
# Saved image_samples/sample-004400-X-Y.png
# Saved image_samples/sample-004400-Y-X.png
# Epoch [ 4410/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2545
# Epoch [ 4420/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.4724
# Epoch [ 4430/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2774
# Epoch [ 4440/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0033 | g_total_loss: 3.2472
# Epoch [ 4450/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1968
# Epoch [ 4460/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0664
# Epoch [ 4470/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0002 | g_total_loss: 3.5284
# Epoch [ 4480/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2564
# Epoch [ 4490/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5221
# Epoch [ 4500/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2341
# Saved image_samples/sample-004500-X-Y.png
# Saved image_samples/sample-004500-Y-X.png
# Epoch [ 4510/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2957
# Epoch [ 4520/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0539 | g_total_loss: 3.4856
# Epoch [ 4530/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.4566
# Epoch [ 4540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2481
# Epoch [ 4550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.4760
# Epoch [ 4560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4294
# Epoch [ 4570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0002 | g_total_loss: 3.1541
# Epoch [ 4580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2633
# Epoch [ 4590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0005 | g_total_loss: 3.2942
# Epoch [ 4600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2603
# Saved image_samples/sample-004600-X-Y.png
# Saved image_samples/sample-004600-Y-X.png
# Epoch [ 4610/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4471
# Epoch [ 4620/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1244
# Epoch [ 4630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3419
# Epoch [ 4640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4011
# Epoch [ 4650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2001
# Epoch [ 4660/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.5473
# Epoch [ 4670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2050
# Epoch [ 4680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3025
# Epoch [ 4690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3094
# Epoch [ 4700/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2506
# Saved image_samples/sample-004700-X-Y.png
# Saved image_samples/sample-004700-Y-X.png
# Epoch [ 4710/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2908
# Epoch [ 4720/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.3526
# Epoch [ 4730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0969
# Epoch [ 4740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1954
# Epoch [ 4750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5222
# Epoch [ 4760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3332
# Epoch [ 4770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2962
# Epoch [ 4780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2385
# Epoch [ 4790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3885
# Epoch [ 4800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3390
# Saved image_samples/sample-004800-X-Y.png
# Saved image_samples/sample-004800-Y-X.png
# Epoch [ 4810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3049
# Epoch [ 4820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2070
# Epoch [ 4830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0012 | g_total_loss: 3.2612
# Epoch [ 4840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1944
# Epoch [ 4850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0123 | g_total_loss: 3.4148
# Epoch [ 4860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.3468
# Epoch [ 4870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3618
# Epoch [ 4880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0015 | g_total_loss: 3.2486
# Epoch [ 4890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3214
# Epoch [ 4900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2475
# Saved image_samples/sample-004900-X-Y.png
# Saved image_samples/sample-004900-Y-X.png
# Epoch [ 4910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3138
# Epoch [ 4920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3982
# Epoch [ 4930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2344
# Epoch [ 4940/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2653
# Epoch [ 4950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.5331 | g_total_loss: 3.3164
# Epoch [ 4960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.9243 | g_total_loss: 2.9223
# Epoch [ 4970/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0003 | g_total_loss: 3.5061
# Epoch [ 4980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2482
# Epoch [ 4990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0002 | g_total_loss: 3.2349
# Epoch [ 5000/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.9325 | g_total_loss: 2.7922
# Saved image_samples/sample-005000-X-Y.png
# Saved image_samples/sample-005000-Y-X.png

# %%
print('Average D_X:', epoch_d_x_loss/100)
print('Average D_Y:', epoch_d_y_loss/100)
print('Average GANs:', epoch_g_loss/100)
# Out:
# Average D_X: 0.24928375598043204
# Average D_Y: 0.23300950228236617
# Average GANs: 4.941380887031555

# %% [markdown]
# #### Training and Loss Patterns

# %%
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, X', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Y', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ### Results

# %%
import matplotlib.image as mpimg

# %%
def view_samples(iteration, sample_dir='/content/image_samples'):
    # samples are named by iteration
    path_XtoY = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    path_YtoX = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))

    # read in those samples
    x2y, y2x = None, None
    try:
        x2y = mpimg.imread(path_XtoY)
        y2x = mpimg.imread(path_YtoX)
    except:
        print('Invalid number of iterations.')

    fig, (ax1, ax2) = plt.subplots(figsize=(18,20), nrows=2, ncols=1, sharey=True, sharex=True)
    ax1.imshow(x2y)
    ax1.set_title('X to Y')
    ax2.imshow(y2x)
    ax2.set_title('Y to X')

# %%
# view samples at iteration 100
view_samples(100)

# %%
# view samples at iteration 5000
view_samples(1000)
