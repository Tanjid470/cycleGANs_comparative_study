# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch import nn, optim

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ### Loading Data

# %%
from PIL import Image

def get_data_loader(image_type, image_dir='/content/drive/MyDrive/ColabNotebooks/DataSet/horse2zebra', image_size=128, batch_size=16, num_workers=0):
    """returns: training and test data loaders for a given image type, either summer or winter"""

    # Resize and normalize the images
    transform = transforms.Compose([
        transforms.Resize((image_size, image_size), interpolation=Image.BICUBIC),  # Resize images to have dimensions (image_size, image_size)
        transforms.ToTensor()  # Convert images to PyTorch tensors
    ])

    # Get training and test directories
    train_path = os.path.join(image_dir, image_type)
    test_path = os.path.join(image_dir, 'test_{}'.format(image_type))

    # Define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)
    test_dataset = datasets.ImageFolder(test_path, transform)

    # Create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    # Retrieve a sample image from the training dataset for visualization
    sample_image, _ = train_dataset[2]


    # Visualize the sample image

    # Display the raw image and transformed image side by side
    plt.figure(figsize=(12, 8))

    plt.subplot(1, 5, 2)
    plt.imshow(sample_image.permute(1, 2, 0))
    plt.title('Original Image')
    plt.axis('off')

    # Display the transformed image
    plt.subplot(1, 5, 4)
    np_image = sample_image.numpy().transpose((1, 2, 0))
    plt.imshow(np_image)
    plt.title('Transformed Image')
    plt.axis('off')

    plt.show()

    return train_loader, test_loader

# %% [markdown]
# ####Resize and Normalize Output Check

# %%
dataloader_X, test_dataloader_X = get_data_loader(image_type='hourse')
dataloader_Y, test_dataloader_Y = get_data_loader(image_type='zebra')

# %%
# display sample images
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_X is your DataLoader
dataiter = iter(dataloader_X)
images, _ = next(dataiter)  # Use next() directly to get the next batch

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# Assuming dataloader_Y is your DataLoader
dataiter = iter(dataloader_Y)

# Get the first batch from the dataloader
for images, _ in dataiter:
    break

# Visualize the batch of images
fig = plt.figure(figsize=(12, 8))
imshow(torchvision.utils.make_grid(images))
plt.show()

# %% [markdown]
# ### Building the Model

# %%
img = images[3]
print('min: ', img.min())
print('max: ', img.max())
# Out:
# min:  tensor(0.0039)
# max:  tensor(1.)

# %%
# Define a helper function for creating convolutional layers
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### Discriminator

# %%
# Discriminator Class
class Discriminator(nn.Module):
    def __init__(self, conv_dim=64):
        super(Discriminator, self).__init__()
        # Define all convolutional layers
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1, batch_norm=False)  # 64x64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 32x32x128
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 16x16x256
        self.conv4 = conv(conv_dim * 4, conv_dim * 8, 4, stride=2, padding=1)  # 8x8x512
        # Final layer
        self.conv5 = nn.Conv2d(conv_dim * 8, 1, 4, stride=1, padding=0, bias=False)  # 1x1x1

    def forward(self, x):
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = nn.ReLU()(self.conv4(out))
        out = self.conv5(out)
        out = torch.sigmoid(out)  # Add sigmoid for output
        return out.view(-1)  # Flatten to 1D for output

# %%
# Residual block definition
class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv(dim, dim, kernel_size=3, stride=1, padding=1)
        self.conv2 = conv(dim, dim, kernel_size=3, stride=1, padding=1, batch_norm=False)

    def forward(self, x):
        residual = x
        x = nn.ReLU()(self.conv1(x))
        x = self.conv2(x)
        return x + residual  # Adding residual for skip connection

# %%
def deconv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(deconv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %% [markdown]
# #### CycleGenerator

# %%
# CycleGenerator Class
class CycleGenerator(nn.Module):
    def __init__(self, conv_dim=64, n_res_blocks=6):
        super(CycleGenerator, self).__init__()
        # 1. Encoder
        self.conv1 = conv(3, conv_dim, 4, stride=2, padding=1)  # 128x128 -> 64x64
        self.conv2 = conv(conv_dim, conv_dim * 2, 4, stride=2, padding=1)  # 64x64 -> 32x32
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, 4, stride=2, padding=1)  # 32x32 -> 16x16

        # 2. Residual blocks
        res_layers = []
        for _ in range(n_res_blocks):
            res_layers.append(ResidualBlock(conv_dim * 4))
        self.res_blocks = nn.Sequential(*res_layers)

        # 3. Decoder
        self.deconv1 = deconv(conv_dim * 4, conv_dim * 2, 4, stride=2, padding=1)  # 16x16 -> 32x32
        self.deconv2 = deconv(conv_dim * 2, conv_dim, 4, stride=2, padding=1)  # 32x32 -> 64x64
        self.deconv3 = deconv(conv_dim, 3, 4, stride=2, padding=1, batch_norm=False)  # 64x64 -> 128x128

    def forward(self, x):
        """Transforms an image and returns it."""
        out = nn.ReLU()(self.conv1(x))
        out = nn.ReLU()(self.conv2(out))
        out = nn.ReLU()(self.conv3(out))
        out = self.res_blocks(out)
        out = nn.ReLU()(self.deconv1(out))
        out = nn.ReLU()(self.deconv2(out))
        # Apply tanh activation to the final output
        out = nn.Tanh()(self.deconv3(out))
        return out

# %% [markdown]
# ### Complete Network

# %%
# Assuming CycleGenerator and Discriminator are defined elsewhere

def create_model(
    g_conv_dim=64,
    d_conv_dim=64,
    n_res_blocks=6,
    device=None
):
    """Builds and initializes generators and discriminators for CycleGAN."""
    # Assign the device if not provided
    if device is None:
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Instantiate generators
    G_XtoY = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)
    G_YtoX = CycleGenerator(conv_dim=g_conv_dim, n_res_blocks=n_res_blocks).to(device)

    # Instantiate discriminators
    D_X = Discriminator(conv_dim=d_conv_dim).to(device)
    D_Y = Discriminator(conv_dim=d_conv_dim).to(device)

    # Log the device information
    if device.type == "cuda":
        print(f"Models moved to GPU: {torch.cuda.get_device_name(device)}.")
    else:
        print("Models using CPU.")

    # Return the initialized models
    return G_XtoY, G_YtoX, D_X, D_Y

# %%
G_XtoY, G_YtoX, D_X, D_Y = create_model()
# Out:
# Models moved to GPU: Tesla T4.

# %%
def print_models(G_XtoY, G_YtoX, D_X, D_Y):
    """Prints model information for the generators and discriminators.
    """
    print("                     G_XtoY                    ")
    print("-----------------------------------------------")
    print(G_XtoY)
    print()

    print("                     G_YtoX                    ")
    print("-----------------------------------------------")
    print(G_YtoX)
    print()

    print("                      D_X                      ")
    print("-----------------------------------------------")
    print(D_X)
    print()

    print("                      D_Y                      ")
    print("-----------------------------------------------")
    print(D_Y)
    print()


# print all of the models
print_models(G_XtoY, G_YtoX, D_X, D_Y)
# Out:
#                      G_XtoY
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                      G_YtoX
# -----------------------------------------------
# CycleGenerator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (res_blocks): Sequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (3): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (4): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (5): ResidualBlock(
#       (conv1): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#                       D_X
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
#
#                       D_Y
# -----------------------------------------------
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %% [markdown]
# #### GANs loss

# %%
def real_mse_loss(D_out):
    # how close is the produced output from being "real"?
    return torch.mean((D_out-1)**2)

# %%
def fake_mse_loss(D_out):
    # how close is the produced output from being "fake"?
    return torch.mean(D_out**2)

# %%
def cycle_consistency_loss(real_im, reconstructed_im, lambda_weight):
    # calculate reconstruction loss
    # as absolute value difference between the real and reconstructed images
    reconstr_loss = torch.mean(torch.abs(real_im - reconstructed_im))
    # return weighted loss
    return lambda_weight*reconstr_loss

# %% [markdown]
# ### Optimizers

# %%
# hyperparams for Adam optimizer
lr=0.0002
beta1=0.5
beta2=0.999 # default value

# %%
# Get generator parameters
g_params = list(G_XtoY.parameters()) + list(G_YtoX.parameters())

# %%
# Create optimizers for the generators and discriminators
g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ### Helper functions

# %%
import pdb
import pickle
import argparse
import scipy
import scipy.misc

# %%
warnings.filterwarnings("ignore")

# %%
def checkpoint(iteration, G_XtoY, G_YtoX, D_X, D_Y, checkpoint_dir='/content/drive/MyDrive/ColabNotebooks/model_checkpoints'):
    """saves the parameters of both generators G_YtoX, G_XtoY and discriminators D_X, D_Y"""
    G_XtoY_path = os.path.join(checkpoint_dir, 'G_XtoY.pkl')
    G_YtoX_path = os.path.join(checkpoint_dir, 'G_YtoX.pkl')
    D_X_path = os.path.join(checkpoint_dir, 'D_X.pkl')
    D_Y_path = os.path.join(checkpoint_dir, 'D_Y.pkl')
    torch.save(G_XtoY.state_dict(), G_XtoY_path)
    torch.save(G_YtoX.state_dict(), G_YtoX_path)
    torch.save(D_X.state_dict(), D_X_path)
    torch.save(D_Y.state_dict(), D_Y_path)

# %%
import numpy as np

def merge_images(sources, targets, batch_size=16):
    """
    Merges source and target image batches into a single image for visualization.

    Args:
    - sources (numpy array): Source images of shape (B, C, H, W).
    - targets (numpy array): Target images of shape (B, C, H, W).
    - batch_size (int): Number of images in each batch.

    Returns:
    - merged (numpy array): Merged image with source and target pairs side-by-side.
    """
    # Check if batch_size matches the number of images
    if len(sources) != batch_size or len(targets) != batch_size:
        raise ValueError("Batch size does not match the number of images in sources or targets.")

    # Get height and width from source images
    _, channels, height, width = sources.shape

    # Calculate number of rows for the merged image (square layout)
    row = int(np.sqrt(batch_size))

    # Initialize an empty array for the merged image
    # This will contain source and target pairs side-by-side
    merged = np.zeros((channels, row * height, row * width * 2))

    # Loop through the batches to fill the merged array
    for idx, (source, target) in enumerate(zip(sources, targets)):
        # Determine row and column index for placement
        row_idx = idx // row
        col_idx = idx % row

        # Place the source and target images into the merged array
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2) * width:(col_idx * 2 + 1) * width] = source
        merged[:, row_idx * height:(row_idx + 1) * height, (col_idx * 2 + 1) * width:(col_idx * 2 + 2) * width] = target

    # Transpose the merged array for the correct (H, W, C) format
    merged = merged.transpose(1, 2, 0)

    return merged

# %%
def to_data(x):
    """converts variable to numpy."""
    if torch.cuda.is_available():
        x = x.cpu()
    x = x.data.numpy()
    x = ((x +1)*255 / (2)).astype(np.uint8) # rescale to 0-255
    return x

# %%
import os
import imageio
def save_samples(iteration, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16, sample_dir='image_samples'):
    """saves samples from both generators X->Y and Y->X."""
    # move input data to correct device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    fake_X = G_YtoX(fixed_Y.to(device))
    fake_Y = G_XtoY(fixed_X.to(device))

    X, fake_X = to_data(fixed_X), to_data(fake_X)
    Y, fake_Y = to_data(fixed_Y), to_data(fake_Y)

    # Create directory if it doesn't exist
    os.makedirs(sample_dir, exist_ok=True)


    merged = merge_images(X, fake_Y, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

    merged = merge_images(Y, fake_X, batch_size)
    merged = merged.astype(np.uint8)
    path = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))
    imageio.imwrite(path, merged)
    print('Saved {}'.format(path))

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ### Training the Model

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1.
       This function assumes that the input x is already scaled from 0-1.'''

    # scale from 0-1 to feature_range
    min, max = feature_range
    x = x * (max - min) + min
    return x

# %%
def unnormalize_images(images):
    """ Return tensor of images to [0:255] space from [-1:1] for plotting. """
    unnormalized = torch.zeros_like(images)
    t = transforms.Normalize(
        mean=[-0.5 / 0.5, -0.5 / 0.5, -0.5 / 0.5],
        std=[1 / 0.5, 1 / 0.5, 1 / 0.5])
    for i, image in enumerate(images):
        unnormalized[i] = t(image)*255
    return unnormalized

# %%
def training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=100):
    print_every=10


    # Create optimizers for the generators and discriminators
    g_optimizer = optim.Adam(g_params, lr, [beta1, beta2])
    d_x_optimizer = optim.Adam(D_X.parameters(), lr, [beta1, beta2])
    d_y_optimizer = optim.Adam(D_Y.parameters(), lr, [beta1, beta2])

    # keep track of losses over time
    losses = []

    test_iter_X = iter(test_dataloader_X)
    test_iter_Y = iter(test_dataloader_Y)

    # Get some fixed data from domains X and Y for sampling. These are images that are held
    # constant throughout training, that allow us to inspect the model's performance.
    fixed_X = next(test_iter_X)[0]
    fixed_Y = next(test_iter_Y)[0]
    fixed_X = scale(fixed_X) # make sure to scale to a range -1 to 1
    fixed_Y = scale(fixed_Y)

    # batches per epoch
    iter_X = iter(dataloader_X)
    iter_Y = iter(dataloader_Y)
    batches_per_epoch = min(len(iter_X), len(iter_Y))

    for epoch in range(1, n_epochs+1):
        # Reset iterators for each epoch
        if epoch % batches_per_epoch == 0:
            iter_X = iter(dataloader_X)
            iter_Y = iter(dataloader_Y)

        images_X, _ = next(iter_X)
        real_images = images_X
        images_X = scale(images_X) # make sure to scale to a range -1 to 1

        images_Y, _ = next(iter_Y)
        real_images = images_Y
        images_Y = scale(images_Y)

        # move images to GPU if available (otherwise stay on CPU)
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        images_X = images_X.to(device)
        images_Y = images_Y.to(device)


        # ============================================
        #            TRAIN THE DISCRIMINATORS
        # ============================================

        ##   First: D_X, real and fake loss components   ##

        # Train with real images
        d_x_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_x = D_X(images_X)
        D_X_real_loss = real_mse_loss(out_x)

        # Train with fake images

        # 2. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 3. Compute the fake loss for D_X
        out_x = D_X(fake_X)
        D_X_fake_loss = fake_mse_loss(out_x)


        # 4. Compute the total loss and perform backprop
        d_x_loss = D_X_real_loss + D_X_fake_loss
        d_x_loss.backward()
        d_x_optimizer.step()


        ##   Second: D_Y, real and fake loss components   ##

        # Train with real images
        d_y_optimizer.zero_grad()

        # 1. Compute the discriminator losses on real images
        out_y = D_Y(images_Y)
        D_Y_real_loss = real_mse_loss(out_y)

        # Train with fake images

        # 2. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 3. Compute the fake loss for D_Y
        out_y = D_Y(fake_Y)
        D_Y_fake_loss = fake_mse_loss(out_y)

        # 4. Compute the total loss and perform backprop
        d_y_loss = D_Y_real_loss + D_Y_fake_loss
        d_y_loss.backward()
        d_y_optimizer.step()


        # =========================================
        #            TRAIN THE GENERATORS
        # =========================================

        ##    First: generate fake X images and reconstructed Y images    ##
        g_optimizer.zero_grad()

        # 1. Generate fake images that look like domain X based on real images in domain Y
        fake_X = G_YtoX(images_Y)

        # 2. Compute the generator loss based on domain X
        out_x = D_X(fake_X)
        g_YtoX_loss = real_mse_loss(out_x)

        # 3. Create a reconstructed y
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_Y = G_XtoY(fake_X)

        reconstructed_y_loss = cycle_consistency_loss(images_Y, reconstructed_Y, lambda_weight=10)


        ##    Second: generate fake Y images and reconstructed X images    ##

        # 1. Generate fake images that look like domain Y based on real images in domain X
        fake_Y = G_XtoY(images_X)

        # 2. Compute the generator loss based on domain Y
        out_y = D_Y(fake_Y)
        g_XtoY_loss = real_mse_loss(out_y)

        # 3. Create a reconstructed x
        # 4. Compute the cycle consistency loss (the reconstruction loss)
        reconstructed_X = G_YtoX(fake_Y)
        reconstructed_x_loss = cycle_consistency_loss(images_X, reconstructed_X, lambda_weight=10)

        # 5. Add up all generator and reconstructed losses and perform backprop
        g_total_loss = g_YtoX_loss + g_XtoY_loss + reconstructed_y_loss + reconstructed_x_loss
        g_total_loss.backward()
        g_optimizer.step()


        # Print the log info
        if epoch % print_every == 0:

            # append real and fake discriminator losses and the generator loss
            losses.append((d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))
            print('Epoch [{:5d}/{:5d}] | d_X_loss: {:6.4f} | d_Y_loss: {:6.4f} | g_total_loss: {:6.4f}'.format(
                    epoch, n_epochs, d_x_loss.item(), d_y_loss.item(), g_total_loss.item()))

             # generate image
            X_fake = G_XtoY(images_X)
            X_fake = unnormalize_images(X_fake)
            images_X = unnormalize_images(images_X)
            grid_image_real = torchvision.utils.make_grid(images_X.cpu())
            grid_image_fake = torchvision.utils.make_grid(X_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))
            # plt.figure(figsize=(20, 10))
            # plt.imshow(saveim)
            # plt.savefig(filename + '_' + 'XtoY.jpg')

            Y_fake = G_YtoX(images_Y)
            Y_fake = unnormalize_images(Y_fake)
            images_Y = unnormalize_images(images_Y)
            grid_image_real = torchvision.utils.make_grid(images_Y.cpu())
            grid_image_fake = torchvision.utils.make_grid(Y_fake.cpu())
            grid_image = torch.cat((grid_image_real, grid_image_fake), 1)
            saveim = np.transpose(grid_image.data.numpy().astype(np.uint8), (1, 2, 0))



        sample_every=100
        # Save the generated samples
        if epoch % sample_every == 0:
            G_YtoX.eval() # set generators to eval mode for sample generation
            G_XtoY.eval()
            save_samples(epoch, fixed_Y, fixed_X, G_YtoX, G_XtoY, batch_size=16)
            G_YtoX.train()
            G_XtoY.train()

        # uncomment these lines, if you want to save your model
        checkpoint_every=1000
        # Save the model parameters
        if epoch % checkpoint_every == 0:
            checkpoint(epoch, G_XtoY, G_YtoX, D_X, D_Y)

    return losses

# %%
n_epochs = 5000
losses = training_loop(dataloader_X, dataloader_Y, test_dataloader_X, test_dataloader_Y, n_epochs=n_epochs)
# Out:
# Epoch [   10/ 5000] | d_X_loss: 0.1703 | d_Y_loss: 0.0078 | g_total_loss: 6.6956
# Epoch [   20/ 5000] | d_X_loss: 0.1877 | d_Y_loss: 0.0078 | g_total_loss: 5.8212
# Epoch [   30/ 5000] | d_X_loss: 0.1608 | d_Y_loss: 0.1432 | g_total_loss: 6.5101
# Epoch [   40/ 5000] | d_X_loss: 0.0631 | d_Y_loss: 0.0047 | g_total_loss: 5.9651
# Epoch [   50/ 5000] | d_X_loss: 0.0551 | d_Y_loss: 0.0129 | g_total_loss: 6.0520
# Epoch [   60/ 5000] | d_X_loss: 0.0632 | d_Y_loss: 0.0059 | g_total_loss: 6.1360
# Epoch [   70/ 5000] | d_X_loss: 0.2873 | d_Y_loss: 0.0030 | g_total_loss: 5.9813
# Epoch [   80/ 5000] | d_X_loss: 0.0921 | d_Y_loss: 0.0714 | g_total_loss: 5.8142
# Epoch [   90/ 5000] | d_X_loss: 0.0841 | d_Y_loss: 0.1583 | g_total_loss: 5.5588
# Epoch [  100/ 5000] | d_X_loss: 0.0255 | d_Y_loss: 0.0354 | g_total_loss: 6.0085
# Saved image_samples/sample-000100-X-Y.png
# Saved image_samples/sample-000100-Y-X.png
# Epoch [  110/ 5000] | d_X_loss: 0.0362 | d_Y_loss: 0.0024 | g_total_loss: 5.5362
# Epoch [  120/ 5000] | d_X_loss: 0.0356 | d_Y_loss: 0.0020 | g_total_loss: 5.3993
# Epoch [  130/ 5000] | d_X_loss: 0.0709 | d_Y_loss: 0.0012 | g_total_loss: 6.1072
# Epoch [  140/ 5000] | d_X_loss: 0.0072 | d_Y_loss: 0.0108 | g_total_loss: 5.8713
# Epoch [  150/ 5000] | d_X_loss: 0.0090 | d_Y_loss: 0.0950 | g_total_loss: 5.4676
# Epoch [  160/ 5000] | d_X_loss: 0.0203 | d_Y_loss: 0.0067 | g_total_loss: 5.6216
# Epoch [  170/ 5000] | d_X_loss: 0.0114 | d_Y_loss: 0.0426 | g_total_loss: 5.6073
# Epoch [  180/ 5000] | d_X_loss: 0.0321 | d_Y_loss: 0.0020 | g_total_loss: 5.6175
# Epoch [  190/ 5000] | d_X_loss: 0.0308 | d_Y_loss: 0.0043 | g_total_loss: 5.2435
# Epoch [  200/ 5000] | d_X_loss: 0.0439 | d_Y_loss: 0.0017 | g_total_loss: 5.4955
# Saved image_samples/sample-000200-X-Y.png
# Saved image_samples/sample-000200-Y-X.png
# Epoch [  210/ 5000] | d_X_loss: 0.0034 | d_Y_loss: 0.0002 | g_total_loss: 5.5434
# Epoch [  220/ 5000] | d_X_loss: 0.0076 | d_Y_loss: 0.0001 | g_total_loss: 5.5146
# Epoch [  230/ 5000] | d_X_loss: 0.2230 | d_Y_loss: 0.0001 | g_total_loss: 5.4198
# Epoch [  240/ 5000] | d_X_loss: 0.0437 | d_Y_loss: 0.0004 | g_total_loss: 5.1573
# Epoch [  250/ 5000] | d_X_loss: 0.0147 | d_Y_loss: 0.0029 | g_total_loss: 5.0080
# Epoch [  260/ 5000] | d_X_loss: 0.0182 | d_Y_loss: 0.0012 | g_total_loss: 5.1278
# Epoch [  270/ 5000] | d_X_loss: 0.0213 | d_Y_loss: 0.0048 | g_total_loss: 5.3168
# Epoch [  280/ 5000] | d_X_loss: 0.0189 | d_Y_loss: 0.0112 | g_total_loss: 5.1614
# Epoch [  290/ 5000] | d_X_loss: 0.0097 | d_Y_loss: 0.0063 | g_total_loss: 5.1903
# Epoch [  300/ 5000] | d_X_loss: 0.0700 | d_Y_loss: 0.0009 | g_total_loss: 4.9890
# Saved image_samples/sample-000300-X-Y.png
# Saved image_samples/sample-000300-Y-X.png
# Epoch [  310/ 5000] | d_X_loss: 0.2168 | d_Y_loss: 0.0049 | g_total_loss: 5.1512
# Epoch [  320/ 5000] | d_X_loss: 0.0308 | d_Y_loss: 0.0114 | g_total_loss: 5.0066
# Epoch [  330/ 5000] | d_X_loss: 0.0164 | d_Y_loss: 0.0026 | g_total_loss: 4.8286
# Epoch [  340/ 5000] | d_X_loss: 0.0023 | d_Y_loss: 0.0001 | g_total_loss: 8.9329
# Epoch [  350/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0001 | g_total_loss: 5.7128
# Epoch [  360/ 5000] | d_X_loss: 0.0087 | d_Y_loss: 0.0000 | g_total_loss: 5.0309
# Epoch [  370/ 5000] | d_X_loss: 0.0101 | d_Y_loss: 0.0001 | g_total_loss: 5.0368
# Epoch [  380/ 5000] | d_X_loss: 0.0086 | d_Y_loss: 0.0002 | g_total_loss: 4.9800
# Epoch [  390/ 5000] | d_X_loss: 0.0131 | d_Y_loss: 0.0001 | g_total_loss: 4.8314
# Epoch [  400/ 5000] | d_X_loss: 0.0131 | d_Y_loss: 0.0000 | g_total_loss: 5.1902
# Saved image_samples/sample-000400-X-Y.png
# Saved image_samples/sample-000400-Y-X.png
# Epoch [  410/ 5000] | d_X_loss: 0.0145 | d_Y_loss: 0.0001 | g_total_loss: 5.2590
# Epoch [  420/ 5000] | d_X_loss: 0.0073 | d_Y_loss: 0.0000 | g_total_loss: 5.0026
# Epoch [  430/ 5000] | d_X_loss: 0.0116 | d_Y_loss: 0.0000 | g_total_loss: 5.0915
# Epoch [  440/ 5000] | d_X_loss: 0.0099 | d_Y_loss: 0.0001 | g_total_loss: 4.7215
# Epoch [  450/ 5000] | d_X_loss: 0.0030 | d_Y_loss: 0.0000 | g_total_loss: 4.7844
# Epoch [  460/ 5000] | d_X_loss: 0.0120 | d_Y_loss: 0.0000 | g_total_loss: 4.8760
# Epoch [  470/ 5000] | d_X_loss: 0.2651 | d_Y_loss: 0.0000 | g_total_loss: 5.0407
# Epoch [  480/ 5000] | d_X_loss: 0.0355 | d_Y_loss: 0.0000 | g_total_loss: 4.7658
# Epoch [  490/ 5000] | d_X_loss: 0.0024 | d_Y_loss: 0.0000 | g_total_loss: 5.3131
# Epoch [  500/ 5000] | d_X_loss: 0.0176 | d_Y_loss: 0.0001 | g_total_loss: 5.0492
# Saved image_samples/sample-000500-X-Y.png
# Saved image_samples/sample-000500-Y-X.png
# Epoch [  510/ 5000] | d_X_loss: 0.0100 | d_Y_loss: 0.0000 | g_total_loss: 4.7703
# Epoch [  520/ 5000] | d_X_loss: 0.0074 | d_Y_loss: 0.0000 | g_total_loss: 4.9735
# Epoch [  530/ 5000] | d_X_loss: 0.0088 | d_Y_loss: 0.0000 | g_total_loss: 5.1535
# Epoch [  540/ 5000] | d_X_loss: 0.0156 | d_Y_loss: 0.0001 | g_total_loss: 5.1689
# Epoch [  550/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0000 | g_total_loss: 4.8087
# Epoch [  560/ 5000] | d_X_loss: 0.0028 | d_Y_loss: 0.0000 | g_total_loss: 5.2775
# Epoch [  570/ 5000] | d_X_loss: 0.0060 | d_Y_loss: 0.0001 | g_total_loss: 4.4628
# Epoch [  580/ 5000] | d_X_loss: 0.0068 | d_Y_loss: 0.0001 | g_total_loss: 4.7691
# Epoch [  590/ 5000] | d_X_loss: 0.0058 | d_Y_loss: 0.0001 | g_total_loss: 5.2878
# Epoch [  600/ 5000] | d_X_loss: 0.0042 | d_Y_loss: 0.0003 | g_total_loss: 4.6789
# Saved image_samples/sample-000600-X-Y.png
# Saved image_samples/sample-000600-Y-X.png
# Epoch [  610/ 5000] | d_X_loss: 0.0052 | d_Y_loss: 0.0002 | g_total_loss: 4.5195
# Epoch [  620/ 5000] | d_X_loss: 0.0088 | d_Y_loss: 0.0040 | g_total_loss: 4.7296
# Epoch [  630/ 5000] | d_X_loss: 0.0050 | d_Y_loss: 0.0004 | g_total_loss: 4.6434
# Epoch [  640/ 5000] | d_X_loss: 0.0070 | d_Y_loss: 0.0005 | g_total_loss: 4.6017
# Epoch [  650/ 5000] | d_X_loss: 0.0079 | d_Y_loss: 0.0075 | g_total_loss: 4.7623
# Epoch [  660/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.6171 | g_total_loss: 4.3734
# Epoch [  670/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0886 | g_total_loss: 4.7833
# Epoch [  680/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0142 | g_total_loss: 5.1719
# Epoch [  690/ 5000] | d_X_loss: 0.0019 | d_Y_loss: 0.0015 | g_total_loss: 4.5400
# Epoch [  700/ 5000] | d_X_loss: 0.0041 | d_Y_loss: 0.0020 | g_total_loss: 4.4439
# Saved image_samples/sample-000700-X-Y.png
# Saved image_samples/sample-000700-Y-X.png
# Epoch [  710/ 5000] | d_X_loss: 0.0032 | d_Y_loss: 0.0013 | g_total_loss: 4.7210
# Epoch [  720/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 5.7477
# Epoch [  730/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0007 | g_total_loss: 4.7866
# Epoch [  740/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0011 | g_total_loss: 5.3866
# Epoch [  750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0031 | g_total_loss: 4.7355
# Epoch [  760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0090 | g_total_loss: 4.6407
# Epoch [  770/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0055 | g_total_loss: 5.1994
# Epoch [  780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0008 | g_total_loss: 4.5385
# Epoch [  790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0009 | g_total_loss: 4.4822
# Epoch [  800/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0012 | g_total_loss: 4.6427
# Saved image_samples/sample-000800-X-Y.png
# Saved image_samples/sample-000800-Y-X.png
# Epoch [  810/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.3882
# Epoch [  820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0004 | g_total_loss: 5.4327
# Epoch [  830/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.8278
# Epoch [  840/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.4113
# Epoch [  850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0002 | g_total_loss: 5.4677
# Epoch [  860/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0006 | g_total_loss: 4.8881
# Epoch [  870/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.9079
# Epoch [  880/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.8281
# Epoch [  890/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.7545
# Epoch [  900/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0004 | g_total_loss: 4.5468
# Saved image_samples/sample-000900-X-Y.png
# Saved image_samples/sample-000900-Y-X.png
# Epoch [  910/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 4.3067
# Epoch [  920/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0008 | g_total_loss: 4.6457
# Epoch [  930/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.4233
# Epoch [  940/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0015 | g_total_loss: 4.3040
# Epoch [  950/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0006 | g_total_loss: 4.7223
# Epoch [  960/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0004 | g_total_loss: 4.2979
# Epoch [  970/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.1210 | g_total_loss: 4.1747
# Epoch [  980/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0537 | g_total_loss: 4.7654
# Epoch [  990/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0029 | g_total_loss: 4.2084
# Epoch [ 1000/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0236 | g_total_loss: 4.2951
# Saved image_samples/sample-001000-X-Y.png
# Saved image_samples/sample-001000-Y-X.png
# Epoch [ 1010/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0079 | g_total_loss: 4.9226
# Epoch [ 1020/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0045 | g_total_loss: 4.4389
# Epoch [ 1030/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0012 | g_total_loss: 4.3274
# Epoch [ 1040/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0008 | g_total_loss: 4.3333
# Epoch [ 1050/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0044 | g_total_loss: 4.2994
# Epoch [ 1060/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0039 | g_total_loss: 4.1934
# Epoch [ 1070/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0011 | g_total_loss: 4.5571
# Epoch [ 1080/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0015 | g_total_loss: 4.2633
# Epoch [ 1090/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0004 | g_total_loss: 4.2778
# Epoch [ 1100/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0023 | g_total_loss: 4.4375
# Saved image_samples/sample-001100-X-Y.png
# Saved image_samples/sample-001100-Y-X.png
# Epoch [ 1110/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0019 | g_total_loss: 4.2751
# Epoch [ 1120/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0004 | g_total_loss: 4.1926
# Epoch [ 1130/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0004 | g_total_loss: 4.5035
# Epoch [ 1140/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0055 | g_total_loss: 4.3062
# Epoch [ 1150/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0007 | g_total_loss: 4.2759
# Epoch [ 1160/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 4.2986
# Epoch [ 1170/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 4.1758
# Epoch [ 1180/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0005 | g_total_loss: 4.2861
# Epoch [ 1190/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0005 | g_total_loss: 4.3187
# Epoch [ 1200/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0003 | g_total_loss: 4.1484
# Saved image_samples/sample-001200-X-Y.png
# Saved image_samples/sample-001200-Y-X.png
# Epoch [ 1210/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.2185
# Epoch [ 1220/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0010 | g_total_loss: 4.3090
# Epoch [ 1230/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0020 | g_total_loss: 4.1842
# Epoch [ 1240/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0021 | g_total_loss: 4.1959
# Epoch [ 1250/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0042 | g_total_loss: 4.1063
# Epoch [ 1260/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0151 | g_total_loss: 4.0561
# Epoch [ 1270/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0014 | g_total_loss: 4.3067
# Epoch [ 1280/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0006 | g_total_loss: 4.7639
# Epoch [ 1290/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0018 | g_total_loss: 4.2338
# Epoch [ 1300/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0018 | g_total_loss: 4.1242
# Saved image_samples/sample-001300-X-Y.png
# Saved image_samples/sample-001300-Y-X.png
# Epoch [ 1310/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0083 | g_total_loss: 4.2458
# Epoch [ 1320/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0003 | g_total_loss: 4.1483
# Epoch [ 1330/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0001 | g_total_loss: 4.2695
# Epoch [ 1340/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0006 | g_total_loss: 4.0099
# Epoch [ 1350/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0011 | g_total_loss: 3.9120
# Epoch [ 1360/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0004 | g_total_loss: 4.0947
# Epoch [ 1370/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0016 | g_total_loss: 4.1002
# Epoch [ 1380/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0003 | g_total_loss: 3.8531
# Epoch [ 1390/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0004 | g_total_loss: 3.8692
# Epoch [ 1400/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.5486
# Saved image_samples/sample-001400-X-Y.png
# Saved image_samples/sample-001400-Y-X.png
# Epoch [ 1410/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0004 | g_total_loss: 4.0868
# Epoch [ 1420/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0005 | g_total_loss: 3.8943
# Epoch [ 1430/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0004 | g_total_loss: 4.3123
# Epoch [ 1440/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0005 | g_total_loss: 3.9095
# Epoch [ 1450/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0002 | g_total_loss: 4.0717
# Epoch [ 1460/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0001 | g_total_loss: 4.1587
# Epoch [ 1470/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0006 | g_total_loss: 4.0531
# Epoch [ 1480/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 4.2126
# Epoch [ 1490/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0005 | g_total_loss: 4.2288
# Epoch [ 1500/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0003 | g_total_loss: 3.9430
# Saved image_samples/sample-001500-X-Y.png
# Saved image_samples/sample-001500-Y-X.png
# Epoch [ 1510/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0008 | g_total_loss: 4.0721
# Epoch [ 1520/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0004 | g_total_loss: 4.0152
# Epoch [ 1530/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0006 | g_total_loss: 4.0374
# Epoch [ 1540/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0727 | g_total_loss: 3.8003
# Epoch [ 1550/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0561 | g_total_loss: 4.4259
# Epoch [ 1560/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0039 | g_total_loss: 4.1215
# Epoch [ 1570/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0017 | g_total_loss: 3.8845
# Epoch [ 1580/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0058 | g_total_loss: 3.9608
# Epoch [ 1590/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0032 | g_total_loss: 3.8362
# Epoch [ 1600/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0014 | g_total_loss: 4.0273
# Saved image_samples/sample-001600-X-Y.png
# Saved image_samples/sample-001600-Y-X.png
# Epoch [ 1610/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0023 | g_total_loss: 4.4103
# Epoch [ 1620/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0008 | g_total_loss: 3.9491
# Epoch [ 1630/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0019 | g_total_loss: 4.2540
# Epoch [ 1640/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0037 | g_total_loss: 3.9093
# Epoch [ 1650/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0011 | g_total_loss: 3.8919
# Epoch [ 1660/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0011 | g_total_loss: 4.0189
# Epoch [ 1670/ 5000] | d_X_loss: 0.0009 | d_Y_loss: 0.0017 | g_total_loss: 4.0291
# Epoch [ 1680/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0021 | g_total_loss: 3.9186
# Epoch [ 1690/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0011 | g_total_loss: 3.8928
# Epoch [ 1700/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0036 | g_total_loss: 3.9432
# Saved image_samples/sample-001700-X-Y.png
# Saved image_samples/sample-001700-Y-X.png
# Epoch [ 1710/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0004 | g_total_loss: 3.8875
# Epoch [ 1720/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0020 | g_total_loss: 3.9094
# Epoch [ 1730/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0004 | g_total_loss: 4.0522
# Epoch [ 1740/ 5000] | d_X_loss: 0.0004 | d_Y_loss: 0.0021 | g_total_loss: 3.9501
# Epoch [ 1750/ 5000] | d_X_loss: 0.0007 | d_Y_loss: 0.0036 | g_total_loss: 3.6721
# Epoch [ 1760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0007 | g_total_loss: 4.0321
# Epoch [ 1770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 4.1699
# Epoch [ 1780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 5.4254
# Epoch [ 1790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 4.6861
# Epoch [ 1800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.1385
# Saved image_samples/sample-001800-X-Y.png
# Saved image_samples/sample-001800-Y-X.png
# Epoch [ 1810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0143
# Epoch [ 1820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.2951
# Epoch [ 1830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8262
# Epoch [ 1840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.9357
# Epoch [ 1850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0896
# Epoch [ 1860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8884
# Epoch [ 1870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7922
# Epoch [ 1880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8842
# Epoch [ 1890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7535
# Epoch [ 1900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7675
# Saved image_samples/sample-001900-X-Y.png
# Saved image_samples/sample-001900-Y-X.png
# Epoch [ 1910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0553
# Epoch [ 1920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6984
# Epoch [ 1930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7827
# Epoch [ 1940/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.8699
# Epoch [ 1950/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.9278
# Epoch [ 1960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7301
# Epoch [ 1970/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 4.4356
# Epoch [ 1980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7610
# Epoch [ 1990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7270
# Epoch [ 2000/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6159
# Saved image_samples/sample-002000-X-Y.png
# Saved image_samples/sample-002000-Y-X.png
# Epoch [ 2010/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7492
# Epoch [ 2020/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4902
# Epoch [ 2030/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6754
# Epoch [ 2040/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7131
# Epoch [ 2050/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6384
# Epoch [ 2060/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7814
# Epoch [ 2070/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.5814
# Epoch [ 2080/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6319
# Epoch [ 2090/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7697
# Epoch [ 2100/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5948
# Saved image_samples/sample-002100-X-Y.png
# Saved image_samples/sample-002100-Y-X.png
# Epoch [ 2110/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6482
# Epoch [ 2120/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.8258
# Epoch [ 2130/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5152
# Epoch [ 2140/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5114
# Epoch [ 2150/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6178
# Epoch [ 2160/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.5030
# Epoch [ 2170/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5139
# Epoch [ 2180/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.8622
# Epoch [ 2190/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5571
# Epoch [ 2200/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5052
# Saved image_samples/sample-002200-X-Y.png
# Saved image_samples/sample-002200-Y-X.png
# Epoch [ 2210/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.5685
# Epoch [ 2220/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.7553
# Epoch [ 2230/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5258
# Epoch [ 2240/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 4.2542
# Epoch [ 2250/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5523
# Epoch [ 2260/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5218
# Epoch [ 2270/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.9588
# Epoch [ 2280/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6005
# Epoch [ 2290/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6597
# Epoch [ 2300/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7384
# Saved image_samples/sample-002300-X-Y.png
# Saved image_samples/sample-002300-Y-X.png
# Epoch [ 2310/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5774
# Epoch [ 2320/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4507
# Epoch [ 2330/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7896
# Epoch [ 2340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4763
# Epoch [ 2350/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5267
# Epoch [ 2360/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7326
# Epoch [ 2370/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4982
# Epoch [ 2380/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4368
# Epoch [ 2390/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7620
# Epoch [ 2400/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.4383
# Saved image_samples/sample-002400-X-Y.png
# Saved image_samples/sample-002400-Y-X.png
# Epoch [ 2410/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5009
# Epoch [ 2420/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.8084
# Epoch [ 2430/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5007
# Epoch [ 2440/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4682
# Epoch [ 2450/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 4.0149
# Epoch [ 2460/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4074
# Epoch [ 2470/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.3178
# Epoch [ 2480/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.9069
# Epoch [ 2490/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6405
# Epoch [ 2500/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4721
# Saved image_samples/sample-002500-X-Y.png
# Saved image_samples/sample-002500-Y-X.png
# Epoch [ 2510/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8159
# Epoch [ 2520/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4767
# Epoch [ 2530/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5855
# Epoch [ 2540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.5095
# Epoch [ 2550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3888
# Epoch [ 2560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5023
# Epoch [ 2570/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6810
# Epoch [ 2580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3951
# Epoch [ 2590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4412
# Epoch [ 2600/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.6942
# Saved image_samples/sample-002600-X-Y.png
# Saved image_samples/sample-002600-Y-X.png
# Epoch [ 2610/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5519
# Epoch [ 2620/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3909
# Epoch [ 2630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6116
# Epoch [ 2640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3869
# Epoch [ 2650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3406
# Epoch [ 2660/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7140
# Epoch [ 2670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.4137
# Epoch [ 2680/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3243
# Epoch [ 2690/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3022
# Epoch [ 2700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4145
# Saved image_samples/sample-002700-X-Y.png
# Saved image_samples/sample-002700-Y-X.png
# Epoch [ 2710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4427
# Epoch [ 2720/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.7257
# Epoch [ 2730/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3274
# Epoch [ 2740/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3099
# Epoch [ 2750/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3927
# Epoch [ 2760/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4322
# Epoch [ 2770/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2576
# Epoch [ 2780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.3564
# Epoch [ 2790/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.4382
# Epoch [ 2800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5748
# Saved image_samples/sample-002800-X-Y.png
# Saved image_samples/sample-002800-Y-X.png
# Epoch [ 2810/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.4472
# Epoch [ 2820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.3526
# Epoch [ 2830/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0002 | g_total_loss: 3.3102
# Epoch [ 2840/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 4.1170
# Epoch [ 2850/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.2294
# Epoch [ 2860/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3616
# Epoch [ 2870/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2592
# Epoch [ 2880/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2742
# Epoch [ 2890/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.3149
# Epoch [ 2900/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.6209
# Saved image_samples/sample-002900-X-Y.png
# Saved image_samples/sample-002900-Y-X.png
# Epoch [ 2910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.5998
# Epoch [ 2920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5572
# Epoch [ 2930/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4253
# Epoch [ 2940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3885
# Epoch [ 2950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4288
# Epoch [ 2960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3806
# Epoch [ 2970/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3410
# Epoch [ 2980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3176
# Epoch [ 2990/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3504
# Epoch [ 3000/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2567
# Saved image_samples/sample-003000-X-Y.png
# Saved image_samples/sample-003000-Y-X.png
# Epoch [ 3010/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2379
# Epoch [ 3020/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.4404
# Epoch [ 3030/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3450
# Epoch [ 3040/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1945
# Epoch [ 3050/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3663
# Epoch [ 3060/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2501
# Epoch [ 3070/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2521
# Epoch [ 3080/ 5000] | d_X_loss: 0.0005 | d_Y_loss: 0.0000 | g_total_loss: 3.3609
# Epoch [ 3090/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3099
# Epoch [ 3100/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2458
# Saved image_samples/sample-003100-X-Y.png
# Saved image_samples/sample-003100-Y-X.png
# Epoch [ 3110/ 5000] | d_X_loss: 0.0006 | d_Y_loss: 0.0000 | g_total_loss: 4.1737
# Epoch [ 3120/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4135
# Epoch [ 3130/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1918
# Epoch [ 3140/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2967
# Epoch [ 3150/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3882
# Epoch [ 3160/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2511
# Epoch [ 3170/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5643
# Epoch [ 3180/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3772
# Epoch [ 3190/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1470
# Epoch [ 3200/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4097
# Saved image_samples/sample-003200-X-Y.png
# Saved image_samples/sample-003200-Y-X.png
# Epoch [ 3210/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2298
# Epoch [ 3220/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1912
# Epoch [ 3230/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3555
# Epoch [ 3240/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0001 | g_total_loss: 3.2000
# Epoch [ 3250/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1508
# Epoch [ 3260/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2461
# Epoch [ 3270/ 5000] | d_X_loss: 0.0002 | d_Y_loss: 0.0000 | g_total_loss: 3.2014
# Epoch [ 3280/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1453
# Epoch [ 3290/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3668
# Epoch [ 3300/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1118
# Saved image_samples/sample-003300-X-Y.png
# Saved image_samples/sample-003300-Y-X.png
# Epoch [ 3310/ 5000] | d_X_loss: 0.0003 | d_Y_loss: 0.0000 | g_total_loss: 3.1869
# Epoch [ 3320/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.5483
# Epoch [ 3330/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2174
# Epoch [ 3340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1235
# Epoch [ 3350/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.3179
# Epoch [ 3360/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.0963
# Epoch [ 3370/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1839
# Epoch [ 3380/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1881
# Epoch [ 3390/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1346
# Epoch [ 3400/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2298
# Saved image_samples/sample-003400-X-Y.png
# Saved image_samples/sample-003400-Y-X.png
# Epoch [ 3410/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.4507
# Epoch [ 3420/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1337
# Epoch [ 3430/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.1755
# Epoch [ 3440/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2971
# Epoch [ 3450/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1652
# Epoch [ 3460/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0001 | g_total_loss: 3.0896
# Epoch [ 3470/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1057
# Epoch [ 3480/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.0497
# Epoch [ 3490/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1007
# Epoch [ 3500/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1066
# Saved image_samples/sample-003500-X-Y.png
# Saved image_samples/sample-003500-Y-X.png
# Epoch [ 3510/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2701
# Epoch [ 3520/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1057
# Epoch [ 3530/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.2396
# Epoch [ 3540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3625
# Epoch [ 3550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2812
# Epoch [ 3560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2865
# Epoch [ 3570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4981
# Epoch [ 3580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1869
# Epoch [ 3590/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.6759
# Epoch [ 3600/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.0832
# Saved image_samples/sample-003600-X-Y.png
# Saved image_samples/sample-003600-Y-X.png
# Epoch [ 3610/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0802
# Epoch [ 3620/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1110
# Epoch [ 3630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1574
# Epoch [ 3640/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.0955
# Epoch [ 3650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3793
# Epoch [ 3660/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.0623
# Epoch [ 3670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1125
# Epoch [ 3680/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.1995
# Epoch [ 3690/ 5000] | d_X_loss: 0.0001 | d_Y_loss: 0.0000 | g_total_loss: 3.0158
# Epoch [ 3700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 7.1458
# Saved image_samples/sample-003700-X-Y.png
# Saved image_samples/sample-003700-Y-X.png
# Epoch [ 3710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 5.3385
# Epoch [ 3720/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 6.3823
# Epoch [ 3730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.7119
# Epoch [ 3740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.4248
# Epoch [ 3750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.7245
# Epoch [ 3760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.1140
# Epoch [ 3770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.9877
# Epoch [ 3780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.7095
# Epoch [ 3790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5940
# Epoch [ 3800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.8166
# Saved image_samples/sample-003800-X-Y.png
# Saved image_samples/sample-003800-Y-X.png
# Epoch [ 3810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3633
# Epoch [ 3820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5575
# Epoch [ 3830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6440
# Epoch [ 3840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4242
# Epoch [ 3850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3332
# Epoch [ 3860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 4.0491
# Epoch [ 3870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3422
# Epoch [ 3880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4375
# Epoch [ 3890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.6438
# Epoch [ 3900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2653
# Saved image_samples/sample-003900-X-Y.png
# Saved image_samples/sample-003900-Y-X.png
# Epoch [ 3910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2238
# Epoch [ 3920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5547
# Epoch [ 3930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3113
# Epoch [ 3940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4081
# Epoch [ 3950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.5139
# Epoch [ 3960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3196
# Epoch [ 3970/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1661
# Epoch [ 3980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2912
# Epoch [ 3990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1294
# Epoch [ 4000/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1135
# Saved image_samples/sample-004000-X-Y.png
# Saved image_samples/sample-004000-Y-X.png
# Epoch [ 4010/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3156
# Epoch [ 4020/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0763
# Epoch [ 4030/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1202
# Epoch [ 4040/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1492
# Epoch [ 4050/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2893
# Epoch [ 4060/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3377
# Epoch [ 4070/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4812
# Epoch [ 4080/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1146
# Epoch [ 4090/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2738
# Epoch [ 4100/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2454
# Saved image_samples/sample-004100-X-Y.png
# Saved image_samples/sample-004100-Y-X.png
# Epoch [ 4110/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0705
# Epoch [ 4120/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0585
# Epoch [ 4130/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0856
# Epoch [ 4140/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0032
# Epoch [ 4150/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2272
# Epoch [ 4160/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.4456
# Epoch [ 4170/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0764
# Epoch [ 4180/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0947
# Epoch [ 4190/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1226
# Epoch [ 4200/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0380
# Saved image_samples/sample-004200-X-Y.png
# Saved image_samples/sample-004200-Y-X.png
# Epoch [ 4210/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9973
# Epoch [ 4220/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0561
# Epoch [ 4230/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0418
# Epoch [ 4240/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0405
# Epoch [ 4250/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0726
# Epoch [ 4260/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2535
# Epoch [ 4270/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1010
# Epoch [ 4280/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2120
# Epoch [ 4290/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1219
# Epoch [ 4300/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9183
# Saved image_samples/sample-004300-X-Y.png
# Saved image_samples/sample-004300-Y-X.png
# Epoch [ 4310/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1294
# Epoch [ 4320/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0125
# Epoch [ 4330/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0211
# Epoch [ 4340/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.2250
# Epoch [ 4350/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9549
# Epoch [ 4360/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0327
# Epoch [ 4370/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1301
# Epoch [ 4380/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0212
# Epoch [ 4390/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9598
# Epoch [ 4400/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.3085
# Saved image_samples/sample-004400-X-Y.png
# Saved image_samples/sample-004400-Y-X.png
# Epoch [ 4410/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9898
# Epoch [ 4420/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0462
# Epoch [ 4430/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1679
# Epoch [ 4440/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0120
# Epoch [ 4450/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0732
# Epoch [ 4460/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0988
# Epoch [ 4470/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9564
# Epoch [ 4480/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9587
# Epoch [ 4490/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0875
# Epoch [ 4500/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9733
# Saved image_samples/sample-004500-X-Y.png
# Saved image_samples/sample-004500-Y-X.png
# Epoch [ 4510/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9729
# Epoch [ 4520/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0493
# Epoch [ 4530/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9921
# Epoch [ 4540/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9780
# Epoch [ 4550/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9826
# Epoch [ 4560/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0230
# Epoch [ 4570/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9727
# Epoch [ 4580/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9799
# Epoch [ 4590/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0423
# Epoch [ 4600/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9520
# Saved image_samples/sample-004600-X-Y.png
# Saved image_samples/sample-004600-Y-X.png
# Epoch [ 4610/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0494
# Epoch [ 4620/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9712
# Epoch [ 4630/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9661
# Epoch [ 4640/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0654
# Epoch [ 4650/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0825
# Epoch [ 4660/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.8722
# Epoch [ 4670/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0050
# Epoch [ 4680/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1304
# Epoch [ 4690/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9786
# Epoch [ 4700/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9967
# Saved image_samples/sample-004700-X-Y.png
# Saved image_samples/sample-004700-Y-X.png
# Epoch [ 4710/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9926
# Epoch [ 4720/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9006
# Epoch [ 4730/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0476
# Epoch [ 4740/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9017
# Epoch [ 4750/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9481
# Epoch [ 4760/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1656
# Epoch [ 4770/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9363
# Epoch [ 4780/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9732
# Epoch [ 4790/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9660
# Epoch [ 4800/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9026
# Saved image_samples/sample-004800-X-Y.png
# Saved image_samples/sample-004800-Y-X.png
# Epoch [ 4810/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0297
# Epoch [ 4820/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9316
# Epoch [ 4830/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9355
# Epoch [ 4840/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9673
# Epoch [ 4850/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.0862
# Epoch [ 4860/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9625
# Epoch [ 4870/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.8865
# Epoch [ 4880/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1013
# Epoch [ 4890/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9884
# Epoch [ 4900/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.8922
# Saved image_samples/sample-004900-X-Y.png
# Saved image_samples/sample-004900-Y-X.png
# Epoch [ 4910/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1782
# Epoch [ 4920/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9022
# Epoch [ 4930/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.8636
# Epoch [ 4940/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9267
# Epoch [ 4950/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9444
# Epoch [ 4960/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.8953
# Epoch [ 4970/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 3.1483
# Epoch [ 4980/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9908
# Epoch [ 4990/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9498
# Epoch [ 5000/ 5000] | d_X_loss: 0.0000 | d_Y_loss: 0.0000 | g_total_loss: 2.9464
# Saved image_samples/sample-005000-X-Y.png
# Saved image_samples/sample-005000-Y-X.png

# %% [markdown]
# #### Training and Loss Patterns

# %%
fig, ax = plt.subplots(figsize=(12,8))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator, X', alpha=0.5)
plt.plot(losses.T[1], label='Discriminator, Y', alpha=0.5)
plt.plot(losses.T[2], label='Generators', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ### Results

# %%
import matplotlib.image as mpimg

# %%
def view_samples(iteration, sample_dir='/content/image_samples'):
    # samples are named by iteration
    path_XtoY = os.path.join(sample_dir, 'sample-{:06d}-X-Y.png'.format(iteration))
    path_YtoX = os.path.join(sample_dir, 'sample-{:06d}-Y-X.png'.format(iteration))

    # read in those samples
    x2y, y2x = None, None
    try:
        x2y = mpimg.imread(path_XtoY)
        y2x = mpimg.imread(path_YtoX)
    except:
        print('Invalid number of iterations.')

    fig, (ax1, ax2) = plt.subplots(figsize=(18,20), nrows=2, ncols=1, sharey=True, sharex=True)
    ax1.imshow(x2y)
    ax1.set_title('X to Y')
    ax2.imshow(y2x)
    ax2.set_title('Y to X')

# %%
# view samples at iteration 100
view_samples(100)

# %%
# view samples at iteration 5000
view_samples(5000)
